# %%
import os
import time
from langchain.document_loaders import UnstructuredMarkdownLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings


# 設定 Markdown 根目錄與向量儲存資料夾
markdown_folder = r"TSpec-LLM/Rel-16"
persist_directory = 'db'
model_name = "sentence-transformers/all-MiniLM-L6-v2"
model_kwargs = {'device': 'cuda'}
embedding = HuggingFaceEmbeddings(model_name=model_name, model_kwargs=model_kwargs)

# 建立 splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=10)
markdown_files = [f for f in os.listdir(markdown_folder) if f.endswith(".md")]
###################################################################################################################################################
# 遞迴抓取所有 .md 檔案
markdown_files = []
for root, _, files in os.walk(markdown_folder):
    for file in files:
        if file.endswith(".md"):
            full_path = os.path.join(root, file)
            markdown_files.append(full_path)

print(f"📁 共發現 {len(markdown_files)} 個 Markdown 檔案\n")
###################################################################################################################################################

# 處理每個 .md 檔案
start_time = time.time()
chunk_summary = {}
persist_root = 'multi_db'

for i, full_path in enumerate(markdown_files, start=1):
    filename = os.path.basename(full_path)
    spec_name = os.path.splitext(filename)[0]

    print(f"\n🔹 處理第 {i}/{len(markdown_files)} 個：{spec_name}")

    loader = UnstructuredMarkdownLoader(full_path)
    documents = loader.load()

    if len(documents) == 0:
        print(f"⚠️  {spec_name} 沒有內容，跳過...\n")
        continue

    for doc in documents:
        doc.metadata["spec"] = spec_name
        doc.metadata["path"] = full_path

    splits = text_splitter.split_documents(documents)
    chunk_summary[spec_name] = len(splits)

    print(f"✅ 完成切割：{spec_name}，共 {len(splits)} 個 chunks")

    if len(splits) == 0:
        print(f"⚠️  {spec_name} 拆分為 0，跳過 embedding...\n")
        continue

    # 建立實體儲存路徑
    persist_path = os.path.join(persist_root, spec_name)
    os.makedirs(persist_path, exist_ok=True)

    Chroma.from_documents(
        documents=splits,
        embedding=embedding,
        persist_directory=persist_path
    ).persist()

    print(f"💾 完成 embedding 並將 {spec_name} 存入 Chroma DB\n")

end_time = time.time()

# ===== 總結所有檔案的 chunks 統計 =====
print("\n📊 檔案切割統計總結：")
total_chunks = 0
for spec, count in chunk_summary.items():
    print(f" - {spec.ljust(20)}: {count} chunks")
    total_chunks += count

print(f"\n📦 總共切割出 {total_chunks} 個 chunks")
print(f"===== Finished Processing in {end_time - start_time:.2f} seconds =====")
# Out:
# 📁 共發現 1697 個 Markdown 檔案
#
#
# 🔹 處理第 1/1697 個：46081-g00
# ✅ 完成切割：46081-g00，共 84 個 chunks
# 💾 完成 embedding 並將 46081-g00 存入 Chroma DB
#
#
# 🔹 處理第 2/1697 個：46053-g00
# ✅ 完成切割：46053-g00，共 48 個 chunks
# 💾 完成 embedding 並將 46053-g00 存入 Chroma DB
#
#
# 🔹 處理第 3/1697 個：46051-g00
# ✅ 完成切割：46051-g00，共 85 個 chunks
# 💾 完成 embedding 並將 46051-g00 存入 Chroma DB
#
#
# 🔹 處理第 4/1697 個：46062-g00
# ✅ 完成切割：46062-g00，共 138 個 chunks
# 💾 完成 embedding 並將 46062-g00 存入 Chroma DB
#
#
# 🔹 處理第 5/1697 個：46020-g00
# ✅ 完成切割：46020-g00，共 424 個 chunks
# 💾 完成 embedding 並將 46020-g00 存入 Chroma DB
#
#
# 🔹 處理第 6/1697 個：46011-g00
# ✅ 完成切割：46011-g00，共 34 個 chunks
# 💾 完成 embedding 並將 46011-g00 存入 Chroma DB
#
#
# 🔹 處理第 7/1697 個：46008-g00
# ✅ 完成切割：46008-g00，共 230 個 chunks
# 💾 完成 embedding 並將 46008-g00 存入 Chroma DB
#
#
# 🔹 處理第 8/1697 個：46002-g00
# ✅ 完成切割：46002-g00，共 81 個 chunks
# 💾 完成 embedding 並將 46002-g00 存入 Chroma DB
#
#
# 🔹 處理第 9/1697 個：46042-g00
# ✅ 完成切割：46042-g00，共 148 個 chunks
# 💾 完成 embedding 並將 46042-g00 存入 Chroma DB
#
#
# 🔹 處理第 10/1697 個：46061-g00
# ✅ 完成切割：46061-g00，共 61 個 chunks
# 💾 完成 embedding 並將 46061-g00 存入 Chroma DB
#
#
# 🔹 處理第 11/1697 個：46010-g00
# ✅ 完成切割：46010-g00，共 542 個 chunks
# 💾 完成 embedding 並將 46010-g00 存入 Chroma DB
#
#
# 🔹 處理第 12/1697 個：46076-g00
# ✅ 完成切割：46076-g00，共 575 個 chunks
# 💾 完成 embedding 並將 46076-g00 存入 Chroma DB
#
#
# 🔹 處理第 13/1697 個：46082-g00
# ✅ 完成切割：46082-g00，共 125 個 chunks
# 💾 完成 embedding 並將 46082-g00 存入 Chroma DB
#
#
# 🔹 處理第 14/1697 個：46022-g00
# ✅ 完成切割：46022-g00，共 96 個 chunks
# 💾 完成 embedding 並將 46022-g00 存入 Chroma DB
#
#
# 🔹 處理第 15/1697 個：46041-g00
# ✅ 完成切割：46041-g00，共 95 個 chunks
# 💾 完成 embedding 並將 46041-g00 存入 Chroma DB
#
#
# 🔹 處理第 16/1697 個：46032-g00
# ✅ 完成切割：46032-g00，共 266 個 chunks
# 💾 完成 embedding 並將 46032-g00 存入 Chroma DB
#
#
# 🔹 處理第 17/1697 個：46085-g00
# ✅ 完成切割：46085-g00，共 245 個 chunks
# 💾 完成 embedding 並將 46085-g00 存入 Chroma DB
#
#
# 🔹 處理第 18/1697 個：readme
# ✅ 完成切割：readme，共 1 個 chunks
# 💾 完成 embedding 並將 readme 存入 Chroma DB
#
#
# 🔹 處理第 19/1697 個：46007-g01
# ✅ 完成切割：46007-g01，共 157 個 chunks
# 💾 完成 embedding 並將 46007-g01 存入 Chroma DB
#
#
# 🔹 處理第 20/1697 個：46060-g00
# ✅ 完成切割：46060-g00，共 457 個 chunks
# 💾 完成 embedding 並將 46060-g00 存入 Chroma DB
#
#
# 🔹 處理第 21/1697 個：46055-g00
# ✅ 完成切割：46055-g00，共 304 個 chunks
# 💾 完成 embedding 並將 46055-g00 存入 Chroma DB
#
#
# 🔹 處理第 22/1697 個：46006-g00
# ✅ 完成切割：46006-g00，共 65 個 chunks
# 💾 完成 embedding 並將 46006-g00 存入 Chroma DB
#
#
# 🔹 處理第 23/1697 個：46021-g00
# ✅ 完成切割：46021-g00，共 75 個 chunks
# 💾 完成 embedding 並將 46021-g00 存入 Chroma DB
#
#
# 🔹 處理第 24/1697 個：46054-g00
# ✅ 完成切割：46054-g00，共 203 個 chunks
# 💾 完成 embedding 並將 46054-g00 存入 Chroma DB
#
#
# 🔹 處理第 25/1697 個：46001-g00
# ✅ 完成切割：46001-g00，共 76 個 chunks
# 💾 完成 embedding 並將 46001-g00 存入 Chroma DB
#
#
# 🔹 處理第 26/1697 個：46012-g00
# ✅ 完成切割：46012-g00，共 43 個 chunks
# 💾 完成 embedding 並將 46012-g00 存入 Chroma DB
#
#
# 🔹 處理第 27/1697 個：46031-g00
# ✅ 完成切割：46031-g00，共 78 個 chunks
# 💾 完成 embedding 並將 46031-g00 存入 Chroma DB
#
#
# 🔹 處理第 28/1697 個：28669-g00
# ✅ 完成切割：28669-g00，共 114 個 chunks
# 💾 完成 embedding 並將 28669-g00 存入 Chroma DB
#
#
# 🔹 處理第 29/1697 個：28736-g00
# ✅ 完成切割：28736-g00，共 127 個 chunks
# 💾 完成 embedding 並將 28736-g00 存入 Chroma DB
#
#
# 🔹 處理第 30/1697 個：28308-g00
# ✅ 完成切割：28308-g00，共 160 個 chunks
# 💾 完成 embedding 並將 28308-g00 存入 Chroma DB
#
#
# 🔹 處理第 31/1697 個：28531-gg0
# ✅ 完成切割：28531-gg0，共 694 個 chunks
# 💾 完成 embedding 並將 28531-gg0 存入 Chroma DB
#
#
# 🔹 處理第 32/1697 個：28313-g40
# ✅ 完成切割：28313-g40，共 423 個 chunks
# 💾 完成 embedding 並將 28313-g40 存入 Chroma DB
#
#
# 🔹 處理第 33/1697 個：28405-g20
# ✅ 完成切割：28405-g20，共 145 個 chunks
# 💾 完成 embedding 並將 28405-g20 存入 Chroma DB
#
#
# 🔹 處理第 34/1697 個：28806-g10
# ✅ 完成切割：28806-g10，共 247 個 chunks
# 💾 完成 embedding 並將 28806-g10 存入 Chroma DB
#
#
# 🔹 處理第 35/1697 個：28809-050
# ✅ 完成切割：28809-050，共 1019 個 chunks
# 💾 完成 embedding 並將 28809-050 存入 Chroma DB
#
#
# 🔹 處理第 36/1697 個：28620-g00
# ✅ 完成切割：28620-g00，共 119 個 chunks
# 💾 完成 embedding 並將 28620-g00 存入 Chroma DB
#
#
# 🔹 處理第 37/1697 個：28732-g00
# ✅ 完成切割：28732-g00，共 108 個 chunks
# 💾 完成 embedding 並將 28732-g00 存入 Chroma DB
#
#
# 🔹 處理第 38/1697 個：28521-g00
# ✅ 完成切割：28521-g00，共 70 個 chunks
# 💾 完成 embedding 並將 28521-g00 存入 Chroma DB
#
#
# 🔹 處理第 39/1697 個：28611-g00
# ✅ 完成切割：28611-g00，共 32 個 chunks
# 💾 完成 embedding 並將 28611-g00 存入 Chroma DB
#
#
# 🔹 處理第 40/1697 個：28890-g00
# ✅ 完成切割：28890-g00，共 510 個 chunks
# 💾 完成 embedding 並將 28890-g00 存入 Chroma DB
#
#
# 🔹 處理第 41/1697 個：28752-g00
# ✅ 完成切割：28752-g00，共 614 個 chunks
# 💾 完成 embedding 並將 28752-g00 存入 Chroma DB
#
#
# 🔹 處理第 42/1697 個：28406-g00
# ✅ 完成切割：28406-g00，共 108 個 chunks
# 💾 完成 embedding 並將 28406-g00 存入 Chroma DB
#
#
# 🔹 處理第 43/1697 個：28515-g00
# ✅ 完成切割：28515-g00，共 119 個 chunks
# 💾 完成 embedding 並將 28515-g00 存入 Chroma DB
#
#
# 🔹 處理第 44/1697 個：28528-g00
# ✅ 完成切割：28528-g00，共 32 個 chunks
# 💾 完成 embedding 並將 28528-g00 存入 Chroma DB
#
#
# 🔹 處理第 45/1697 個：28312-010
# ✅ 完成切割：28312-010，共 69 個 chunks
# 💾 完成 embedding 並將 28312-010 存入 Chroma DB
#
#
# 🔹 處理第 46/1697 個：28616-g00
# ✅ 完成切割：28616-g00，共 86 個 chunks
# 💾 完成 embedding 並將 28616-g00 存入 Chroma DB
#
#
# 🔹 處理第 47/1697 個：SP-200480 Presentation of Report to TSG TR 28.810 Version 1.0.0
# ✅ 完成切割：SP-200480 Presentation of Report to TSG TR 28.810 Version 1.0.0，共 4 個 chunks
# 💾 完成 embedding 並將 SP-200480 Presentation of Report to TSG TR 28.810 Version 1.0.0 存入 Chroma DB
#
#
# 🔹 處理第 48/1697 個：28675-g00
# ✅ 完成切割：28675-g00，共 81 個 chunks
# 💾 完成 embedding 並將 28675-g00 存入 Chroma DB
#
#
# 🔹 處理第 49/1697 個：28703-g00
# ✅ 完成切割：28703-g00，共 233 個 chunks
# 💾 完成 embedding 並將 28703-g00 存入 Chroma DB
#
#
# 🔹 處理第 50/1697 個：28513-g00
# ✅ 完成切割：28513-g00，共 29 個 chunks
# 💾 完成 embedding 並將 28513-g00 存入 Chroma DB
#
#
# 🔹 處理第 51/1697 個：28805-g10
# ✅ 完成切割：28805-g10，共 457 個 chunks
# 💾 完成 embedding 並將 28805-g10 存入 Chroma DB
#
#
# 🔹 處理第 52/1697 個：28672-g00
# ✅ 完成切割：28672-g00，共 102 個 chunks
# 💾 完成 embedding 並將 28672-g00 存入 Chroma DB
#
#
# 🔹 處理第 53/1697 個：28303-g00
# ✅ 完成切割：28303-g00，共 123 個 chunks
# 💾 完成 embedding 並將 28303-g00 存入 Chroma DB
#
#
# 🔹 處理第 54/1697 個：28662-g00
# ✅ 完成切割：28662-g00，共 207 個 chunks
# 💾 完成 embedding 並將 28662-g00 存入 Chroma DB
#
#
# 🔹 處理第 55/1697 個：28520-g00
# ✅ 完成切割：28520-g00，共 155 個 chunks
# 💾 完成 embedding 並將 28520-g00 存入 Chroma DB
#
#
# 🔹 處理第 56/1697 個：28803-g01
# ✅ 完成切割：28803-g01，共 163 個 chunks
# 💾 完成 embedding 並將 28803-g01 存入 Chroma DB
#
#
# 🔹 處理第 57/1697 個：28624-g00
# ✅ 完成切割：28624-g00，共 46 個 chunks
# 💾 完成 embedding 並將 28624-g00 存入 Chroma DB
#
#
# 🔹 處理第 58/1697 個：28654-g00
# ✅ 完成切割：28654-g00，共 25 個 chunks
# 💾 完成 embedding 並將 28654-g00 存入 Chroma DB
#
#
# 🔹 處理第 59/1697 個：28667-g00
# ✅ 完成切割：28667-g00，共 66 個 chunks
# 💾 完成 embedding 並將 28667-g00 存入 Chroma DB
#
#
# 🔹 處理第 60/1697 個：28305-g00
# ✅ 完成切割：28305-g00，共 268 個 chunks
# 💾 完成 embedding 並將 28305-g00 存入 Chroma DB
#
#
# 🔹 處理第 61/1697 個：28517-g00
# ✅ 完成切割：28517-g00，共 56 個 chunks
# 💾 完成 embedding 並將 28517-g00 存入 Chroma DB
#
#
# 🔹 處理第 62/1697 個：28621-g00
# ✅ 完成切割：28621-g00，共 36 個 chunks
# 💾 完成 embedding 並將 28621-g00 存入 Chroma DB
#
#
# 🔹 處理第 63/1697 個：28516-g00
# ✅ 完成切割：28516-g00，共 68 個 chunks
# 💾 完成 embedding 並將 28516-g00 存入 Chroma DB
#
#
# 🔹 處理第 64/1697 個：28751-g00
# ✅ 完成切割：28751-g00，共 24 個 chunks
# 💾 完成 embedding 並將 28751-g00 存入 Chroma DB
#
#
# 🔹 處理第 65/1697 個：28541-gh0_cover_c3
# ✅ 完成切割：28541-gh0_cover_c3，共 181 個 chunks
# 💾 完成 embedding 並將 28541-gh0_cover_c3 存入 Chroma DB
#
#
# 🔹 處理第 66/1697 個：28518-g00
# ✅ 完成切割：28518-g00，共 31 個 chunks
# 💾 完成 embedding 並將 28518-g00 存入 Chroma DB
#
#
# 🔹 處理第 67/1697 個：28810-100
# ✅ 完成切割：28810-100，共 317 個 chunks
# 💾 完成 embedding 並將 28810-100 存入 Chroma DB
#
#
# 🔹 處理第 68/1697 個：28404-g40
# ✅ 完成切割：28404-g40，共 80 個 chunks
# 💾 完成 embedding 並將 28404-g40 存入 Chroma DB
#
#
# 🔹 處理第 69/1697 個：28541-gh0_AnnexesE_G
# ✅ 完成切割：28541-gh0_AnnexesE_G，共 945 個 chunks
# 💾 完成 embedding 並將 28541-gh0_AnnexesE_G 存入 Chroma DB
#
#
# 🔹 處理第 70/1697 個：28302-g00
# ✅ 完成切割：28302-g00，共 196 個 chunks
# 💾 完成 embedding 並將 28302-g00 存入 Chroma DB
#
#
# 🔹 處理第 71/1697 個：28535-g60
# ✅ 完成切割：28535-g60，共 182 個 chunks
# 💾 完成 embedding 並將 28535-g60 存入 Chroma DB
#
#
# 🔹 處理第 72/1697 個：28530-g60
# ✅ 完成切割：28530-g60，共 359 個 chunks
# 💾 完成 embedding 並將 28530-g60 存入 Chroma DB
#
#
# 🔹 處理第 73/1697 個：28734-g00
# ✅ 完成切割：28734-g00，共 42 個 chunks
# 💾 完成 embedding 並將 28734-g00 存入 Chroma DB
#
#
# 🔹 處理第 74/1697 個：28681-g00
# ✅ 完成切割：28681-g00，共 22 個 chunks
# 💾 完成 embedding 並將 28681-g00 存入 Chroma DB
#
#
# 🔹 處理第 75/1697 個：28512-g00
# ✅ 完成切割：28512-g00，共 30 個 chunks
# 💾 完成 embedding 並將 28512-g00 存入 Chroma DB
#
#
# 🔹 處理第 76/1697 個：28310-g70
# ✅ 完成切割：28310-g70，共 264 個 chunks
# 💾 完成 embedding 並將 28310-g70 存入 Chroma DB
#
#
# 🔹 處理第 77/1697 個：28706-g00
# ✅ 完成切割：28706-g00，共 244 個 chunks
# 💾 完成 embedding 並將 28706-g00 存入 Chroma DB
#
#
# 🔹 處理第 78/1697 個：28311-g00
# ✅ 完成切割：28311-g00，共 293 個 chunks
# 💾 完成 embedding 並將 28311-g00 存入 Chroma DB
#
#
# 🔹 處理第 79/1697 個：28554-ge0
# ✅ 完成切割：28554-ge0，共 321 個 chunks
# 💾 完成 embedding 並將 28554-ge0 存入 Chroma DB
#
#
# 🔹 處理第 80/1697 個：28707-g00
# ✅ 完成切割：28707-g00，共 44 個 chunks
# 💾 完成 embedding 並將 28707-g00 存入 Chroma DB
#
#
# 🔹 處理第 81/1697 個：28622-gh0
# ✅ 完成切割：28622-gh0，共 726 個 chunks
# 💾 完成 embedding 並將 28622-gh0 存入 Chroma DB
#
#
# 🔹 處理第 82/1697 個：28632-g00
# ✅ 完成切割：28632-g00，共 177 個 chunks
# 💾 完成 embedding 並將 28632-g00 存入 Chroma DB
#
#
# 🔹 處理第 83/1697 個：28655-g00
# ✅ 完成切割：28655-g00，共 140 個 chunks
# 💾 完成 embedding 並將 28655-g00 存入 Chroma DB
#
#
# 🔹 處理第 84/1697 個：28708-g00
# ✅ 完成切割：28708-g00，共 148 個 chunks
# 💾 完成 embedding 並將 28708-g00 存入 Chroma DB
#
#
# 🔹 處理第 85/1697 個：28653-g00
# ✅ 完成切割：28653-g00，共 474 個 chunks
# 💾 完成 embedding 並將 28653-g00 存入 Chroma DB
#
#
# 🔹 處理第 86/1697 個：28631-g00
# ✅ 完成切割：28631-g00，共 29 個 chunks
# 💾 完成 embedding 並將 28631-g00 存入 Chroma DB
#
#
# 🔹 處理第 87/1697 個：28533-ga0
# ✅ 完成切割：28533-ga0，共 225 個 chunks
# 💾 完成 embedding 並將 28533-ga0 存入 Chroma DB
#
#
# 🔹 處理第 88/1697 個：28628-g10
# ✅ 完成切割：28628-g10，共 547 個 chunks
# 💾 完成 embedding 並將 28628-g10 存入 Chroma DB
#
#
# 🔹 處理第 89/1697 個：28626-g00
# ✅ 完成切割：28626-g00，共 107 個 chunks
# 💾 完成 embedding 並將 28626-g00 存入 Chroma DB
#
#
# 🔹 處理第 90/1697 個：28683-g00
# ✅ 完成切割：28683-g00，共 24 個 chunks
# 💾 完成 embedding 並將 28683-g00 存入 Chroma DB
#
#
# 🔹 處理第 91/1697 個：28661-g00
# ✅ 完成切割：28661-g00，共 31 個 chunks
# 💾 完成 embedding 並將 28661-g00 存入 Chroma DB
#
#
# 🔹 處理第 92/1697 個：28651-g00
# ✅ 完成切割：28651-g00，共 25 個 chunks
# 💾 完成 embedding 並將 28651-g00 存入 Chroma DB
#
#
# 🔹 處理第 93/1697 個：28668-g00
# ✅ 完成切割：28668-g00，共 93 個 chunks
# 💾 完成 embedding 並將 28668-g00 存入 Chroma DB
#
#
# 🔹 處理第 94/1697 個：28657-g00
# ✅ 完成切割：28657-g00，共 44 個 chunks
# 💾 完成 embedding 並將 28657-g00 存入 Chroma DB
#
#
# 🔹 處理第 95/1697 個：28532-gg0
# ✅ 完成切割：28532-gg0，共 2334 個 chunks
# 💾 完成 embedding 並將 28532-gg0 存入 Chroma DB
#
#
# 🔹 處理第 96/1697 個：28623-gf0
# ✅ 完成切割：28623-gf0，共 786 個 chunks
# 💾 完成 embedding 並將 28623-gf0 存入 Chroma DB
#
#
# 🔹 處理第 97/1697 個：28541-gh0_AnnexesA_D
# ✅ 完成切割：28541-gh0_AnnexesA_D，共 433 個 chunks
# 💾 完成 embedding 並將 28541-gh0_AnnexesA_D 存入 Chroma DB
#
#
# 🔹 處理第 98/1697 個：28201-g20
# ✅ 完成切割：28201-g20，共 217 個 chunks
# 💾 完成 embedding 並將 28201-g20 存入 Chroma DB
#
#
# 🔹 處理第 99/1697 個：28537-g00
# ✅ 完成切割：28537-g00，共 75 個 chunks
# 💾 完成 embedding 並將 28537-g00 存入 Chroma DB
#
#
# 🔹 處理第 100/1697 個：28500-g00
# ✅ 完成切割：28500-g00，共 303 個 chunks
# 💾 完成 embedding 並將 28500-g00 存入 Chroma DB
#
#
# 🔹 處理第 101/1697 個：28612-g00
# ✅ 完成切割：28612-g00，共 59 個 chunks
# 💾 完成 embedding 並將 28612-g00 存入 Chroma DB
#
#
# 🔹 處理第 102/1697 個：28731-g00
# ✅ 完成切割：28731-g00，共 29 個 chunks
# 💾 完成 embedding 並將 28731-g00 存入 Chroma DB
#
#
# 🔹 處理第 103/1697 個：28403-g00
# ✅ 完成切割：28403-g00，共 69 個 chunks
# 💾 完成 embedding 並將 28403-g00 存入 Chroma DB
#
#
# 🔹 處理第 104/1697 個：28304-g00
# ✅ 完成切割：28304-g00，共 146 個 chunks
# 💾 完成 embedding 並將 28304-g00 存入 Chroma DB
#
#
# 🔹 處理第 105/1697 個：28510-g00
# ✅ 完成切割：28510-g00，共 182 個 chunks
# 💾 完成 embedding 並將 28510-g00 存入 Chroma DB
#
#
# 🔹 處理第 106/1697 個：28522-g00
# ✅ 完成切割：28522-g00，共 31 個 chunks
# 💾 完成 embedding 並將 28522-g00 存入 Chroma DB
#
#
# 🔹 處理第 107/1697 個：28552-gg0
# ✅ 完成切割：28552-gg0，共 2028 個 chunks
# 💾 完成 embedding 並將 28552-gg0 存入 Chroma DB
#
#
# 🔹 處理第 108/1697 個：28704-g00
# ✅ 完成切割：28704-g00，共 25 個 chunks
# 💾 完成 embedding 並將 28704-g00 存入 Chroma DB
#
#
# 🔹 處理第 109/1697 個：28625-g00
# ✅ 完成切割：28625-g00，共 54 個 chunks
# 💾 完成 embedding 並將 28625-g00 存入 Chroma DB
#
#
# 🔹 處理第 110/1697 個：28709-g00
# ✅ 完成切割：28709-g00，共 211 個 chunks
# 💾 完成 embedding 並將 28709-g00 存入 Chroma DB
#
#
# 🔹 處理第 111/1697 個：28527-g00
# ✅ 完成切割：28527-g00，共 28 個 chunks
# 💾 完成 embedding 並將 28527-g00 存入 Chroma DB
#
#
# 🔹 處理第 112/1697 個：28702-g00
# ✅ 完成切割：28702-g00，共 223 個 chunks
# 💾 完成 embedding 並將 28702-g00 存入 Chroma DB
#
#
# 🔹 處理第 113/1697 個：28525-g00
# ✅ 完成切割：28525-g00，共 771 個 chunks
# 💾 完成 embedding 並將 28525-g00 存入 Chroma DB
#
#
# 🔹 處理第 114/1697 個：28301-g00
# ✅ 完成切割：28301-g00，共 204 個 chunks
# 💾 完成 embedding 並將 28301-g00 存入 Chroma DB
#
#
# 🔹 處理第 115/1697 個：28526-g00
# ✅ 完成切割：28526-g00，共 334 個 chunks
# 💾 完成 embedding 並將 28526-g00 存入 Chroma DB
#
#
# 🔹 處理第 116/1697 個：28627-g00
# ✅ 完成切割：28627-g00，共 328 個 chunks
# 💾 完成 embedding 並將 28627-g00 存入 Chroma DB
#
#
# 🔹 處理第 117/1697 個：28753-g00
# ✅ 完成切割：28753-g00，共 237 個 chunks
# 💾 完成 embedding 並將 28753-g00 存入 Chroma DB
#
#
# 🔹 處理第 118/1697 個：28202-g10
# ✅ 完成切割：28202-g10，共 168 個 chunks
# 💾 完成 embedding 並將 28202-g10 存入 Chroma DB
#
#
# 🔹 處理第 119/1697 個：28390-g00
# ✅ 完成切割：28390-g00，共 86 個 chunks
# 💾 完成 embedding 並將 28390-g00 存入 Chroma DB
#
#
# 🔹 處理第 120/1697 個：28306-g00
# ✅ 完成切割：28306-g00，共 361 個 chunks
# 💾 完成 embedding 並將 28306-g00 存入 Chroma DB
#
#
# 🔹 處理第 121/1697 個：28680-g00
# ✅ 完成切割：28680-g00，共 80 個 chunks
# 💾 完成 embedding 並將 28680-g00 存入 Chroma DB
#
#
# 🔹 處理第 122/1697 個：28550-g90
# ✅ 完成切割：28550-g90，共 899 個 chunks
# 💾 完成 embedding 並將 28550-g90 存入 Chroma DB
#
#
# 🔹 處理第 123/1697 個：28705-g00
# ✅ 完成切割：28705-g00，共 136 個 chunks
# 💾 完成 embedding 並將 28705-g00 存入 Chroma DB
#
#
# 🔹 處理第 124/1697 個：28523-g00
# ✅ 完成切割：28523-g00，共 27 個 chunks
# 💾 完成 embedding 並將 28523-g00 存入 Chroma DB
#
#
# 🔹 處理第 125/1697 個：28536-g50
# ✅ 完成切割：28536-g50，共 175 個 chunks
# 💾 完成 embedding 並將 28536-g50 存入 Chroma DB
#
#
# 🔹 處理第 126/1697 個：28673-g00
# ✅ 完成切割：28673-g00，共 74 個 chunks
# 💾 完成 embedding 並將 28673-g00 存入 Chroma DB
#
#
# 🔹 處理第 127/1697 個：28659-g20
# ✅ 完成切割：28659-g20，共 436 個 chunks
# 💾 完成 embedding 並將 28659-g20 存入 Chroma DB
#
#
# 🔹 處理第 128/1697 個：28658-g40
# ✅ 完成切割：28658-g40，共 531 個 chunks
# 💾 完成 embedding 並將 28658-g40 存入 Chroma DB
#
#
# 🔹 處理第 129/1697 個：28541-gh0_c04_c07
# ✅ 完成切割：28541-gh0_c04_c07，共 867 個 chunks
# 💾 完成 embedding 並將 28541-gh0_c04_c07 存入 Chroma DB
#
#
# 🔹 處理第 130/1697 個：28682-g00
# ✅ 完成切割：28682-g00，共 42 個 chunks
# 💾 完成 embedding 並將 28682-g00 存入 Chroma DB
#
#
# 🔹 處理第 131/1697 個：28676-g00
# ✅ 完成切割：28676-g00，共 66 個 chunks
# 💾 完成 embedding 並將 28676-g00 存入 Chroma DB
#
#
# 🔹 處理第 132/1697 個：28309-g00
# ✅ 完成切割：28309-g00，共 235 個 chunks
# 💾 完成 embedding 並將 28309-g00 存入 Chroma DB
#
#
# 🔹 處理第 133/1697 個：28402-g00
# ✅ 完成切割：28402-g00，共 55 個 chunks
# 💾 完成 embedding 並將 28402-g00 存入 Chroma DB
#
#
# 🔹 處理第 134/1697 個：28735-g00
# ✅ 完成切割：28735-g00，共 107 個 chunks
# 💾 完成 embedding 並將 28735-g00 存入 Chroma DB
#
#
# 🔹 處理第 135/1697 個：28656-g00
# ✅ 完成切割：28656-g00，共 106 個 chunks
# 💾 完成 embedding 並將 28656-g00 存入 Chroma DB
#
#
# 🔹 處理第 136/1697 個：28807-120
# ✅ 完成切割：28807-120，共 290 個 chunks
# 💾 完成 embedding 並將 28807-120 存入 Chroma DB
#
#
# 🔹 處理第 137/1697 個：28062-g00
# ✅ 完成切割：28062-g00，共 2126 個 chunks
# 💾 完成 embedding 並將 28062-g00 存入 Chroma DB
#
#
# 🔹 處理第 138/1697 個：28671-g00
# ✅ 完成切割：28671-g00，共 36 個 chunks
# 💾 完成 embedding 並將 28671-g00 存入 Chroma DB
#
#
# 🔹 處理第 139/1697 個：28861-g00
# ✅ 完成切割：28861-g00，共 477 個 chunks
# 💾 完成 embedding 並將 28861-g00 存入 Chroma DB
#
#
# 🔹 處理第 140/1697 個：28701-g00
# ✅ 完成切割：28701-g00，共 49 個 chunks
# 💾 完成 embedding 並將 28701-g00 存入 Chroma DB
#
#
# 🔹 處理第 141/1697 個：28307-g00
# ✅ 完成切割：28307-g00，共 69 個 chunks
# 💾 完成 embedding 並將 28307-g00 存入 Chroma DB
#
#
# 🔹 處理第 142/1697 個：28541-gh0_AnnexesH_History
# ✅ 完成切割：28541-gh0_AnnexesH_History，共 672 個 chunks
# 💾 完成 embedding 並將 28541-gh0_AnnexesH_History 存入 Chroma DB
#
#
# 🔹 處理第 143/1697 個：28808-050
# ✅ 完成切割：28808-050，共 197 個 chunks
# 💾 完成 embedding 並將 28808-050 存入 Chroma DB
#
#
# 🔹 處理第 144/1697 個：28511-g00
# ✅ 完成切割：28511-g00，共 55 個 chunks
# 💾 完成 embedding 並將 28511-g00 存入 Chroma DB
#
#
# 🔹 處理第 145/1697 個：28733-g00
# ✅ 完成切割：28733-g00，共 97 個 chunks
# 💾 完成 embedding 並將 28733-g00 存入 Chroma DB
#
#
# 🔹 處理第 146/1697 個：28804-g01
# ✅ 完成切割：28804-g01，共 99 個 chunks
# 💾 完成 embedding 並將 28804-g01 存入 Chroma DB
#
#
# 🔹 處理第 147/1697 個：28629-g00
# ✅ 完成切割：28629-g00，共 164 個 chunks
# 💾 完成 embedding 並將 28629-g00 存入 Chroma DB
#
#
# 🔹 處理第 148/1697 個：28663-g00
# ✅ 完成切割：28663-g00，共 148 個 chunks
# 💾 完成 embedding 並將 28663-g00 存入 Chroma DB
#
#
# 🔹 處理第 149/1697 個：28812-0a0
# ✅ 完成切割：28812-0a0，共 500 個 chunks
# 💾 完成 embedding 並將 28812-0a0 存入 Chroma DB
#
#
# 🔹 處理第 150/1697 個：28633-g00
# ✅ 完成切割：28633-g00，共 91 個 chunks
# 💾 完成 embedding 並將 28633-g00 存入 Chroma DB
#
#
# 🔹 處理第 151/1697 個：28540-g20
# ✅ 完成切割：28540-g20，共 60 個 chunks
# 💾 完成 embedding 並將 28540-g20 存入 Chroma DB
#
#
# 🔹 處理第 152/1697 個：28652-g00
# ✅ 完成切割：28652-g00，共 304 個 chunks
# 💾 完成 embedding 並將 28652-g00 存入 Chroma DB
#
#
# 🔹 處理第 153/1697 個：28545-g10
# ✅ 完成切割：28545-g10，共 382 個 chunks
# 💾 完成 embedding 並將 28545-g10 存入 Chroma DB
#
#
# 🔹 處理第 154/1697 個：28674-g00
# ✅ 完成切割：28674-g00，共 34 個 chunks
# 💾 完成 embedding 並將 28674-g00 存入 Chroma DB
#
#
# 🔹 處理第 155/1697 個：45009-g00
# ✅ 完成切割：45009-g00，共 295 個 chunks
# 💾 完成 embedding 並將 45009-g00 存入 Chroma DB
#
#
# 🔹 處理第 156/1697 個：45015-g00
# ✅ 完成切割：45015-g00，共 34 個 chunks
# 💾 完成 embedding 並將 45015-g00 存入 Chroma DB
#
#
# 🔹 處理第 157/1697 個：45050-g00
# ✅ 完成切割：45050-g00，共 3755 個 chunks
# 💾 完成 embedding 並將 45050-g00 存入 Chroma DB
#
#
# 🔹 處理第 158/1697 個：45903-g00
# ✅ 完成切割：45903-g00，共 623 個 chunks
# 💾 完成 embedding 並將 45903-g00 存入 Chroma DB
#
#
# 🔹 處理第 159/1697 個：45003-g00
# ✅ 完成切割：45003-g00，共 3157 個 chunks
# 💾 完成 embedding 並將 45003-g00 存入 Chroma DB
#
#
# 🔹 處理第 160/1697 個：45001-g00
# ✅ 完成切割：45001-g00，共 620 個 chunks
# 💾 完成 embedding 並將 45001-g00 存入 Chroma DB
#
#
# 🔹 處理第 161/1697 個：45022-g00
# ✅ 完成切割：45022-g00，共 307 個 chunks
# 💾 完成 embedding 並將 45022-g00 存入 Chroma DB
#
#
# 🔹 處理第 162/1697 個：45902-g01
# ✅ 完成切割：45902-g01，共 326 個 chunks
# 💾 完成 embedding 並將 45902-g01 存入 Chroma DB
#
#
# 🔹 處理第 163/1697 個：45926-g00
# ✅ 完成切割：45926-g00，共 706 個 chunks
# 💾 完成 embedding 並將 45926-g00 存入 Chroma DB
#
#
# 🔹 處理第 164/1697 個：45912-g00
# ✅ 完成切割：45912-g00，共 4657 個 chunks
# 💾 完成 embedding 並將 45912-g00 存入 Chroma DB
#
#
# 🔹 處理第 165/1697 個：45913-g00
# ✅ 完成切割：45913-g00，共 240 個 chunks
# 💾 完成 embedding 並將 45913-g00 存入 Chroma DB
#
#
# 🔹 處理第 166/1697 個：45056-g00
# ✅ 完成切割：45056-g00，共 242 個 chunks
# 💾 完成 embedding 並將 45056-g00 存入 Chroma DB
#
#
# 🔹 處理第 167/1697 個：45005-g10
# ✅ 完成切割：45005-g10，共 4512 個 chunks
# 💾 完成 embedding 並將 45005-g10 存入 Chroma DB
#
#
# 🔹 處理第 168/1697 個：45004-g00
# ✅ 完成切割：45004-g00，共 139 個 chunks
# 💾 完成 embedding 並將 45004-g00 存入 Chroma DB
#
#
# 🔹 處理第 169/1697 個：45010-g00
# ✅ 完成切割：45010-g00，共 465 個 chunks
# 💾 完成 embedding 並將 45010-g00 存入 Chroma DB
#
#
# 🔹 處理第 170/1697 個：45002-g10
# ✅ 完成切割：45002-g10，共 1860 個 chunks
# 💾 完成 embedding 並將 45002-g10 存入 Chroma DB
#
#
# 🔹 處理第 171/1697 個：45008-g00
# ✅ 完成切割：45008-g00，共 2854 個 chunks
# 💾 完成 embedding 並將 45008-g00 存入 Chroma DB
#
#
# 🔹 處理第 172/1697 個：41101-g00
# ✅ 完成切割：41101-g00，共 31 個 chunks
# 💾 完成 embedding 並將 41101-g00 存入 Chroma DB
#
#
# 🔹 處理第 173/1697 個：41031-g00
# ✅ 完成切割：41031-g00，共 58 個 chunks
# 💾 完成 embedding 並將 41031-g00 存入 Chroma DB
#
#
# 🔹 處理第 174/1697 個：52402-g00
# ✅ 完成切割：52402-g00，共 1445 個 chunks
# 💾 完成 embedding 並將 52402-g00 存入 Chroma DB
#
#
# 🔹 處理第 175/1697 個：52008-g00
# ✅ 完成切割：52008-g00，共 542 個 chunks
# 💾 完成 embedding 並將 52008-g00 存入 Chroma DB
#
#
# 🔹 處理第 176/1697 個：52021-g00
# ✅ 完成切割：52021-g00，共 491 個 chunks
# 💾 完成 embedding 並將 52021-g00 存入 Chroma DB
#
#
# 🔹 處理第 177/1697 個：32666-g00
# ✅ 完成切割：32666-g00，共 275 個 chunks
# 💾 完成 embedding 並將 32666-g00 存入 Chroma DB
#
#
# 🔹 處理第 178/1697 個：32111-6-g00
# ✅ 完成切割：32111-6-g00，共 853 個 chunks
# 💾 完成 embedding 並將 32111-6-g00 存入 Chroma DB
#
#
# 🔹 處理第 179/1697 個：32107-g10
# ✅ 完成切割：32107-g10，共 192 個 chunks
# 💾 完成 embedding 並將 32107-g10 存入 Chroma DB
#
#
# 🔹 處理第 180/1697 個：32582-g00
# ✅ 完成切割：32582-g00，共 221 個 chunks
# 💾 完成 embedding 並將 32582-g00 存入 Chroma DB
#
#
# 🔹 處理第 181/1697 個：32531-g00
# ✅ 完成切割：32531-g00，共 152 個 chunks
# 💾 完成 embedding 並將 32531-g00 存入 Chroma DB
#
#
# 🔹 處理第 182/1697 個：32276-g00
# ✅ 完成切割：32276-g00，共 244 個 chunks
# 💾 完成 embedding 並將 32276-g00 存入 Chroma DB
#
#
# 🔹 處理第 183/1697 個：32351-g00
# ✅ 完成切割：32351-g00，共 49 個 chunks
# 💾 完成 embedding 並將 32351-g00 存入 Chroma DB
#
#
# 🔹 處理第 184/1697 個：32121-g00
# ✅ 完成切割：32121-g00，共 40 個 chunks
# 💾 完成 embedding 並將 32121-g00 存入 Chroma DB
#
#
# 🔹 處理第 185/1697 個：32366-g00
# ✅ 完成切割：32366-g00，共 242 個 chunks
# 💾 完成 embedding 並將 32366-g00 存入 Chroma DB
#
#
# 🔹 處理第 186/1697 個：32416-g00
# ✅ 完成切割：32416-g00，共 542 個 chunks
# 💾 完成 embedding 並將 32416-g00 存入 Chroma DB
#
#
# 🔹 處理第 187/1697 個：32255-ge0
# ✅ 完成切割：32255-ge0，共 1249 個 chunks
# 💾 完成 embedding 並將 32255-ge0 存入 Chroma DB
#
#
# 🔹 處理第 188/1697 個：32126-g00
# ✅ 完成切割：32126-g00，共 165 個 chunks
# 💾 完成 embedding 並將 32126-g00 存入 Chroma DB
#
#
# 🔹 處理第 189/1697 個：32583-g00
# ✅ 完成切割：32583-g00，共 122 個 chunks
# 💾 完成 embedding 並將 32583-g00 存入 Chroma DB
#
#
# 🔹 處理第 190/1697 個：32381-g00
# ✅ 完成切割：32381-g00，共 40 個 chunks
# 💾 完成 embedding 並將 32381-g00 存入 Chroma DB
#
#
# 🔹 處理第 191/1697 個：32281-g10
# ✅ 完成切割：32281-g10，共 208 個 chunks
# 💾 完成 embedding 並將 32281-g10 存入 Chroma DB
#
#
# 🔹 處理第 192/1697 個：32250-g00
# ✅ 完成切割：32250-g00，共 1281 個 chunks
# 💾 完成 embedding 並將 32250-g00 存入 Chroma DB
#
#
# 🔹 處理第 193/1697 個：32341-g00
# ✅ 完成切割：32341-g00，共 51 個 chunks
# 💾 完成 embedding 並將 32341-g00 存入 Chroma DB
#
#
# 🔹 處理第 194/1697 個：32275-g10
# ✅ 完成切割：32275-g10，共 622 個 chunks
# 💾 完成 embedding 並將 32275-g10 存入 Chroma DB
#
#
# 🔹 處理第 195/1697 個：32306-g00
# ✅ 完成切割：32306-g00，共 437 個 chunks
# 💾 完成 embedding 並將 32306-g00 存入 Chroma DB
#
#
# 🔹 處理第 196/1697 個：32572-g00
# ✅ 完成切割：32572-g00，共 56 個 chunks
# 💾 完成 embedding 並將 32572-g00 存入 Chroma DB
#
#
# 🔹 處理第 197/1697 個：32311-g00
# ✅ 完成切割：32311-g00，共 40 個 chunks
# 💾 完成 embedding 並將 32311-g00 存入 Chroma DB
#
#
# 🔹 處理第 198/1697 個：32584-g00
# ✅ 完成切割：32584-g00，共 250 個 chunks
# 💾 完成 embedding 並將 32584-g00 存入 Chroma DB
#
#
# 🔹 處理第 199/1697 個：32601-g00
# ✅ 完成切割：32601-g00，共 53 個 chunks
# 💾 完成 embedding 並將 32601-g00 存入 Chroma DB
#
#
# 🔹 處理第 200/1697 個：32412-g00
# ✅ 完成切割：32412-g00，共 507 個 chunks
# 💾 完成 embedding 並將 32412-g00 存入 Chroma DB
#
#
# 🔹 處理第 201/1697 個：32450-g00
# ✅ 完成切割：32450-g00，共 89 個 chunks
# 💾 完成 embedding 並將 32450-g00 存入 Chroma DB
#
#
# 🔹 處理第 202/1697 個：32277-g00
# ✅ 完成切割：32277-g00，共 1187 個 chunks
# 💾 完成 embedding 並將 32277-g00 存入 Chroma DB
#
#
# 🔹 處理第 203/1697 個：32298-gc0
# ✅ 完成切割：32298-gc0，共 2375 個 chunks
# 💾 完成 embedding 並將 32298-gc0 存入 Chroma DB
#
#
# 🔹 處理第 204/1697 個：32141-g00
# ✅ 完成切割：32141-g00，共 62 個 chunks
# 💾 完成 embedding 並將 32141-g00 存入 Chroma DB
#
#
# 🔹 處理第 205/1697 個：32130-g00
# ✅ 完成切割：32130-g00，共 96 個 chunks
# 💾 完成 embedding 並將 32130-g00 存入 Chroma DB
#
#
# 🔹 處理第 206/1697 個：32312-g00
# ✅ 完成切割：32312-g00，共 89 個 chunks
# 💾 完成 embedding 並將 32312-g00 存入 Chroma DB
#
#
# 🔹 處理第 207/1697 個：32409-g00
# ✅ 完成切割：32409-g00，共 1086 個 chunks
# 💾 完成 embedding 並將 32409-g00 存入 Chroma DB
#
#
# 🔹 處理第 208/1697 個：32102-g00
# ✅ 完成切割：32102-g00，共 369 個 chunks
# 💾 完成 embedding 並將 32102-g00 存入 Chroma DB
#
#
# 🔹 處理第 209/1697 個：32508-g00
# ✅ 完成切割：32508-g00，共 112 個 chunks
# 💾 完成 embedding 並將 32508-g00 存入 Chroma DB
#
#
# 🔹 處理第 210/1697 個：32391-g00
# ✅ 完成切割：32391-g00，共 66 個 chunks
# 💾 完成 embedding 並將 32391-g00 存入 Chroma DB
#
#
# 🔹 處理第 211/1697 個：32436-g00
# ✅ 完成切割：32436-g00，共 56 個 chunks
# 💾 完成 embedding 並將 32436-g00 存入 Chroma DB
#
#
# 🔹 處理第 212/1697 個：32386-g00
# ✅ 完成切割：32386-g00，共 207 個 chunks
# 💾 完成 embedding 並將 32386-g00 存入 Chroma DB
#
#
# 🔹 處理第 213/1697 個：32616-g00
# ✅ 完成切割：32616-g00，共 804 個 chunks
# 💾 完成 embedding 並將 32616-g00 存入 Chroma DB
#
#
# 🔹 處理第 214/1697 個：32251-g00
# ✅ 完成切割：32251-g00，共 2479 個 chunks
# 💾 完成 embedding 並將 32251-g00 存入 Chroma DB
#
#
# 🔹 處理第 215/1697 個：32342-g00
# ✅ 完成切割：32342-g00，共 143 個 chunks
# 💾 完成 embedding 並將 32342-g00 存入 Chroma DB
#
#
# 🔹 處理第 216/1697 個：32260-g30_clean
# ✅ 完成切割：32260-g30_clean，共 2122 個 chunks
# 💾 完成 embedding 並將 32260-g30_clean 存入 Chroma DB
#
#
# 🔹 處理第 217/1697 個：32111-1-g00
# ✅ 完成切割：32111-1-g00，共 286 個 chunks
# 💾 完成 embedding 並將 32111-1-g00 存入 Chroma DB
#
#
# 🔹 處理第 218/1697 個：32153-g00
# ✅ 完成切割：32153-g00，共 224 個 chunks
# 💾 完成 embedding 並將 32153-g00 存入 Chroma DB
#
#
# 🔹 處理第 219/1697 個：32571-g00
# ✅ 完成切割：32571-g00，共 52 個 chunks
# 💾 完成 embedding 並將 32571-g00 存入 Chroma DB
#
#
# 🔹 處理第 220/1697 個：32361-g00
# ✅ 完成切割：32361-g00，共 57 個 chunks
# 💾 完成 embedding 並將 32361-g00 存入 Chroma DB
#
#
# 🔹 處理第 221/1697 個：32271-g00
# ✅ 完成切割：32271-g00，共 214 個 chunks
# 💾 完成 embedding 並將 32271-g00 存入 Chroma DB
#
#
# 🔹 處理第 222/1697 個：32299-g20
# ✅ 完成切割：32299-g20，共 1847 個 chunks
# 💾 完成 embedding 並將 32299-g20 存入 Chroma DB
#
#
# 🔹 處理第 223/1697 個：32612-g00
# ✅ 完成切割：32612-g00，共 476 個 chunks
# 💾 完成 embedding 並將 32612-g00 存入 Chroma DB
#
#
# 🔹 處理第 224/1697 個：32280-g00
# ✅ 完成切割：32280-g00，共 362 個 chunks
# 💾 完成 embedding 並將 32280-g00 存入 Chroma DB
#
#
# 🔹 處理第 225/1697 個：32332-g00
# ✅ 完成切割：32332-g00，共 212 個 chunks
# 💾 完成 embedding 並將 32332-g00 存入 Chroma DB
#
#
# 🔹 處理第 226/1697 個：32432-g00
# ✅ 完成切割：32432-g00，共 169 個 chunks
# 💾 完成 embedding 並將 32432-g00 存入 Chroma DB
#
#
# 🔹 處理第 227/1697 個：32591-g00
# ✅ 完成切割：32591-g00，共 169 個 chunks
# 💾 完成 embedding 並將 32591-g00 存入 Chroma DB
#
#
# 🔹 處理第 228/1697 個：32321-g00
# ✅ 完成切割：32321-g00，共 89 個 chunks
# 💾 完成 embedding 並將 32321-g00 存入 Chroma DB
#
#
# 🔹 處理第 229/1697 個：32454-g00
# ✅ 完成切割：32454-g00，共 78 個 chunks
# 💾 完成 embedding 並將 32454-g00 存入 Chroma DB
#
#
# 🔹 處理第 230/1697 個：32410-g00
# ✅ 完成切割：32410-g00，共 217 個 chunks
# 💾 完成 embedding 並將 32410-g00 存入 Chroma DB
#
#
# 🔹 處理第 231/1697 個：32272-g00
# ✅ 完成切割：32272-g00，共 444 個 chunks
# 💾 完成 embedding 並將 32272-g00 存入 Chroma DB
#
#
# 🔹 處理第 232/1697 個：32316-g00
# ✅ 完成切割：32316-g00，共 128 個 chunks
# 💾 完成 embedding 並將 32316-g00 存入 Chroma DB
#
#
# 🔹 處理第 233/1697 個：32602-g00
# ✅ 完成切割：32602-g00，共 236 個 chunks
# 💾 完成 embedding 並將 32602-g00 存入 Chroma DB
#
#
# 🔹 處理第 234/1697 個：32423-g90
# ✅ 完成切割：32423-g90，共 1704 個 chunks
# 💾 完成 embedding 並將 32423-g90 存入 Chroma DB
#
#
# 🔹 處理第 235/1697 個：32401-g00
# ✅ 完成切割：32401-g00，共 384 個 chunks
# 💾 完成 embedding 並將 32401-g00 存入 Chroma DB
#
#
# 🔹 處理第 236/1697 個：32611-g00
# ✅ 完成切割：32611-g00，共 113 個 chunks
# 💾 完成 embedding 並將 32611-g00 存入 Chroma DB
#
#
# 🔹 處理第 237/1697 個：32594-g00
# ✅ 完成切割：32594-g00，共 100 個 chunks
# 💾 完成 embedding 並將 32594-g00 存入 Chroma DB
#
#
# 🔹 處理第 238/1697 個：32396-g00
# ✅ 完成切割：32396-g00，共 406 個 chunks
# 💾 完成 embedding 並將 32396-g00 存入 Chroma DB
#
#
# 🔹 處理第 239/1697 個：32101-g00
# ✅ 完成切割：32101-g00，共 622 個 chunks
# 💾 完成 embedding 並將 32101-g00 存入 Chroma DB
#
#
# 🔹 處理第 240/1697 個：32158-gb0
# ✅ 完成切割：32158-gb0，共 809 個 chunks
# 💾 完成 embedding 並將 32158-gb0 存入 Chroma DB
#
#
# 🔹 處理第 241/1697 個：32421-g30
# ✅ 完成切割：32421-g30，共 441 個 chunks
# 💾 完成 embedding 並將 32421-g30 存入 Chroma DB
#
#
# 🔹 處理第 242/1697 個：32376-g00
# ✅ 完成切割：32376-g00，共 239 個 chunks
# 💾 完成 embedding 並將 32376-g00 存入 Chroma DB
#
#
# 🔹 處理第 243/1697 個：32291-gf0
# ✅ 完成切割：32291-gf0，共 1473 個 chunks
# 💾 完成 embedding 並將 32291-gf0 存入 Chroma DB
#
#
# 🔹 處理第 244/1697 個：32346-g00
# ✅ 完成切割：32346-g00，共 246 個 chunks
# 💾 完成 embedding 並將 32346-g00 存入 Chroma DB
#
#
# 🔹 處理第 245/1697 個：32382-g00
# ✅ 完成切割：32382-g00，共 112 個 chunks
# 💾 完成 embedding 並將 32382-g00 存入 Chroma DB
#
#
# 🔹 處理第 246/1697 個：32442-g00
# ✅ 完成切割：32442-g00，共 280 個 chunks
# 💾 完成 embedding 並將 32442-g00 存入 Chroma DB
#
#
# 🔹 處理第 247/1697 個：32422-gc0
# ✅ 完成切割：32422-gc0，共 1930 個 chunks
# 💾 完成 embedding 並將 32422-gc0 存入 Chroma DB
#
#
# 🔹 處理第 248/1697 個：32301-g00
# ✅ 完成切割：32301-g00，共 49 個 chunks
# 💾 完成 embedding 並將 32301-g00 存入 Chroma DB
#
#
# 🔹 處理第 249/1697 個：32592-g00
# ✅ 完成切割：32592-g00，共 1160 個 chunks
# 💾 完成 embedding 並將 32592-g00 存入 Chroma DB
#
#
# 🔹 處理第 250/1697 個：32506-g00
# ✅ 完成切割：32506-g00，共 391 個 chunks
# 💾 完成 embedding 並將 32506-g00 存入 Chroma DB
#
#
# 🔹 處理第 251/1697 個：32551-g00
# ✅ 完成切割：32551-g00，共 256 個 chunks
# 💾 完成 embedding 並將 32551-g00 存入 Chroma DB
#
#
# 🔹 處理第 252/1697 個：32300-g00
# ✅ 完成切割：32300-g00，共 238 個 chunks
# 💾 完成 embedding 並將 32300-g00 存入 Chroma DB
#
#
# 🔹 處理第 253/1697 個：32240-g50
# ✅ 完成切割：32240-g50，共 668 個 chunks
# 💾 完成 embedding 並將 32240-g50 存入 Chroma DB
#
#
# 🔹 處理第 254/1697 個：32371-g00
# ✅ 完成切割：32371-g00，共 347 個 chunks
# 💾 完成 embedding 並將 32371-g00 存入 Chroma DB
#
#
# 🔹 處理第 255/1697 個：32425-g50
# ✅ 完成切割：32425-g50，共 1192 個 chunks
# 💾 完成 embedding 並將 32425-g50 存入 Chroma DB
#
#
# 🔹 處理第 256/1697 個：32322-g00
# ✅ 完成切割：32322-g00，共 260 個 chunks
# 💾 完成 embedding 並將 32322-g00 存入 Chroma DB
#
#
# 🔹 處理第 257/1697 個：32845-g00
# ✅ 完成切割：32845-g00，共 394 個 chunks
# 💾 完成 embedding 並將 32845-g00 存入 Chroma DB
#
#
# 🔹 處理第 258/1697 個：32256-g30
# ✅ 完成切割：32256-g30，共 369 個 chunks
# 💾 完成 embedding 並將 32256-g30 存入 Chroma DB
#
#
# 🔹 處理第 259/1697 個：32404-g00
# ✅ 完成切割：32404-g00，共 308 個 chunks
# 💾 完成 embedding 並將 32404-g00 存入 Chroma DB
#
#
# 🔹 處理第 260/1697 個：32661-g00
# ✅ 完成切割：32661-g00，共 58 個 chunks
# 💾 完成 embedding 並將 32661-g00 存入 Chroma DB
#
#
# 🔹 處理第 261/1697 個：32352-g00
# ✅ 完成切割：32352-g00，共 129 個 chunks
# 💾 完成 embedding 並將 32352-g00 存入 Chroma DB
#
#
# 🔹 處理第 262/1697 個：32326-g00
# ✅ 完成切割：32326-g00，共 248 個 chunks
# 💾 完成 embedding 並將 32326-g00 存入 Chroma DB
#
#
# 🔹 處理第 263/1697 個：32452-g00
# ✅ 完成切割：32452-g00，共 280 個 chunks
# 💾 完成 embedding 並將 32452-g00 存入 Chroma DB
#
#
# 🔹 處理第 264/1697 個：32122-g00
# ✅ 完成切割：32122-g00，共 162 個 chunks
# 💾 完成 embedding 並將 32122-g00 存入 Chroma DB
#
#
# 🔹 處理第 265/1697 個：32501-g00
# ✅ 完成切割：32501-g00，共 172 個 chunks
# 💾 完成 embedding 並將 32501-g00 存入 Chroma DB
#
#
# 🔹 處理第 266/1697 個：32453-g00
# ✅ 完成切割：32453-g00，共 302 個 chunks
# 💾 完成 embedding 並將 32453-g00 存入 Chroma DB
#
#
# 🔹 處理第 267/1697 個：32297-g20
# ✅ 完成切割：32297-g20，共 249 個 chunks
# 💾 完成 embedding 並將 32297-g20 存入 Chroma DB
#
#
# 🔹 處理第 268/1697 個：32426-g00
# ✅ 完成切割：32426-g00，共 810 個 chunks
# 💾 完成 embedding 並將 32426-g00 存入 Chroma DB
#
#
# 🔹 處理第 269/1697 個：32156-g80
# ✅ 完成切割：32156-g80，共 291 個 chunks
# 💾 完成 embedding 並將 32156-g80 存入 Chroma DB
#
#
# 🔹 處理第 270/1697 個：32302-g00
# ✅ 完成切割：32302-g00，共 238 個 chunks
# 💾 完成 embedding 並將 32302-g00 存入 Chroma DB
#
#
# 🔹 處理第 271/1697 個：32140-g00
# ✅ 完成切割：32140-g00，共 369 個 chunks
# 💾 完成 embedding 並將 32140-g00 存入 Chroma DB
#
#
# 🔹 處理第 272/1697 個：32154-g00
# ✅ 完成切割：32154-g00，共 86 個 chunks
# 💾 完成 embedding 並將 32154-g00 存入 Chroma DB
#
#
# 🔹 處理第 273/1697 個：32411-g00
# ✅ 完成切割：32411-g00，共 62 個 chunks
# 💾 完成 embedding 並將 32411-g00 存入 Chroma DB
#
#
# 🔹 處理第 274/1697 個：32362-g00
# ✅ 完成切割：32362-g00，共 110 個 chunks
# 💾 完成 embedding 並將 32362-g00 存入 Chroma DB
#
#
# 🔹 處理第 275/1697 個：32502-g00
# ✅ 完成切割：32502-g00，共 225 個 chunks
# 💾 完成 embedding 並將 32502-g00 存入 Chroma DB
#
#
# 🔹 處理第 276/1697 個：32509-g00
# ✅ 完成切割：32509-g00，共 82 個 chunks
# 💾 完成 embedding 並將 32509-g00 存入 Chroma DB
#
#
# 🔹 處理第 277/1697 個：32182-g00
# ✅ 完成切割：32182-g00，共 85 個 chunks
# 💾 完成 embedding 並將 32182-g00 存入 Chroma DB
#
#
# 🔹 處理第 278/1697 個：32972-g10
# ✅ 完成切割：32972-g10，共 260 個 chunks
# 💾 完成 embedding 並將 32972-g10 存入 Chroma DB
#
#
# 🔹 處理第 279/1697 個：32500-g00
# ✅ 完成切割：32500-g00，共 115 個 chunks
# 💾 完成 embedding 並將 32500-g00 存入 Chroma DB
#
#
# 🔹 處理第 280/1697 個：32662-g00
# ✅ 完成切割：32662-g00，共 188 個 chunks
# 💾 完成 embedding 並將 32662-g00 存入 Chroma DB
#
#
# 🔹 處理第 281/1697 個：32441-g00
# ✅ 完成切割：32441-g00，共 112 個 chunks
# 💾 完成 embedding 並將 32441-g00 存入 Chroma DB
#
#
# 🔹 處理第 282/1697 個：32408-g00
# ✅ 完成切割：32408-g00，共 331 個 chunks
# 💾 完成 embedding 並將 32408-g00 存入 Chroma DB
#
#
# 🔹 處理第 283/1697 個：32356-g00
# ✅ 完成切割：32356-g00，共 189 個 chunks
# 💾 完成 embedding 並將 32356-g00 存入 Chroma DB
#
#
# 🔹 處理第 284/1697 個：32293-g00
# ✅ 完成切割：32293-g00，共 111 個 chunks
# 💾 完成 embedding 並將 32293-g00 存入 Chroma DB
#
#
# 🔹 處理第 285/1697 個：32278-g00
# ✅ 完成切割：32278-g00，共 307 個 chunks
# 💾 完成 embedding 並將 32278-g00 存入 Chroma DB
#
#
# 🔹 處理第 286/1697 個：32407-g00
# ✅ 完成切割：32407-g00，共 621 個 chunks
# 💾 完成 embedding 並將 32407-g00 存入 Chroma DB
#
#
# 🔹 處理第 287/1697 個：32155-g10
# ✅ 完成切割：32155-g10，共 42 個 chunks
# 💾 完成 embedding 並將 32155-g10 存入 Chroma DB
#
#
# 🔹 處理第 288/1697 個：32581-g00
# ✅ 完成切割：32581-g00，共 86 個 chunks
# 💾 完成 embedding 並將 32581-g00 存入 Chroma DB
#
#
# 🔹 處理第 289/1697 個：32372-g00
# ✅ 完成切割：32372-g00，共 127 個 chunks
# 💾 完成 embedding 並將 32372-g00 存入 Chroma DB
#
#
# 🔹 處理第 290/1697 個：32606-g00
# ✅ 完成切割：32606-g00，共 327 個 chunks
# 💾 完成 embedding 並將 32606-g00 存入 Chroma DB
#
#
# 🔹 處理第 291/1697 個：32290-ga0
# ✅ 完成切割：32290-ga0，共 342 個 chunks
# 💾 完成 embedding 並將 32290-ga0 存入 Chroma DB
#
#
# 🔹 處理第 292/1697 個：32253-g00
# ✅ 完成切割：32253-g00，共 288 個 chunks
# 💾 完成 embedding 並將 32253-g00 存入 Chroma DB
#
#
# 🔹 處理第 293/1697 個：32536-g00
# ✅ 完成切割：32536-g00，共 647 個 chunks
# 💾 完成 embedding 並將 32536-g00 存入 Chroma DB
#
#
# 🔹 處理第 294/1697 個：32273-g00
# ✅ 完成切割：32273-g00，共 384 個 chunks
# 💾 完成 embedding 並將 32273-g00 存入 Chroma DB
#
#
# 🔹 處理第 295/1697 個：32451-g00
# ✅ 完成切割：32451-g00，共 108 個 chunks
# 💾 完成 embedding 並將 32451-g00 存入 Chroma DB
#
#
# 🔹 處理第 296/1697 個：32690-g00
# ✅ 完成切割：32690-g00，共 98 個 chunks
# 💾 完成 embedding 並將 32690-g00 存入 Chroma DB
#
#
# 🔹 處理第 297/1697 個：32160-g70
# ✅ 完成切割：32160-g70，共 442 個 chunks
# 💾 完成 embedding 並將 32160-g70 存入 Chroma DB
#
#
# 🔹 處理第 298/1697 個：32336-g00
# ✅ 完成切割：32336-g00，共 373 個 chunks
# 💾 完成 embedding 並將 32336-g00 存入 Chroma DB
#
#
# 🔹 處理第 299/1697 個：32593-g00
# ✅ 完成切割：32593-g00，共 145 個 chunks
# 💾 完成 embedding 並將 32593-g00 存入 Chroma DB
#
#
# 🔹 處理第 300/1697 個：32600-g00
# ✅ 完成切割：32600-g00，共 232 個 chunks
# 💾 完成 embedding 並將 32600-g00 存入 Chroma DB
#
#
# 🔹 處理第 301/1697 個：32274-g40
# ✅ 完成切割：32274-g40，共 807 個 chunks
# 💾 完成 embedding 並將 32274-g40 存入 Chroma DB
#
#
# 🔹 處理第 302/1697 個：32296-g00
# ✅ 完成切割：32296-g00，共 803 個 chunks
# 💾 完成 embedding 並將 32296-g00 存入 Chroma DB
#
#
# 🔹 處理第 303/1697 個：32331-g00
# ✅ 完成切割：32331-g00，共 82 個 chunks
# 💾 完成 embedding 並將 32331-g00 存入 Chroma DB
#
#
# 🔹 處理第 304/1697 個：32392-g00
# ✅ 完成切割：32392-g00，共 205 個 chunks
# 💾 完成 embedding 並將 32392-g00 存入 Chroma DB
#
#
# 🔹 處理第 305/1697 個：32157-g00
# ✅ 完成切割：32157-g00，共 287 個 chunks
# 💾 完成 embedding 並將 32157-g00 存入 Chroma DB
#
#
# 🔹 處理第 306/1697 個：32455-g00
# ✅ 完成切割：32455-g00，共 72 個 chunks
# 💾 完成 embedding 並將 32455-g00 存入 Chroma DB
#
#
# 🔹 處理第 307/1697 個：32446-g00
# ✅ 完成切割：32446-g00，共 435 個 chunks
# 💾 完成 embedding 並將 32446-g00 存入 Chroma DB
#
#
# 🔹 處理第 308/1697 個：32254-g60
# ✅ 完成切割：32254-g60，共 274 個 chunks
# 💾 完成 embedding 並將 32254-g60 存入 Chroma DB
#
#
# 🔹 處理第 309/1697 個：32295-g00
# ✅ 完成切割：32295-g00，共 289 個 chunks
# 💾 完成 embedding 並將 32295-g00 存入 Chroma DB
#
#
# 🔹 處理第 310/1697 個：32103-g30
# ✅ 完成切割：32103-g30，共 439 個 chunks
# 💾 完成 embedding 並將 32103-g30 存入 Chroma DB
#
#
# 🔹 處理第 311/1697 個：32541-g00
# ✅ 完成切割：32541-g00，共 168 個 chunks
# 💾 完成 embedding 並將 32541-g00 存入 Chroma DB
#
#
# 🔹 處理第 312/1697 個：32111-2-g00
# ✅ 完成切割：32111-2-g00，共 687 個 chunks
# 💾 完成 embedding 並將 32111-2-g00 存入 Chroma DB
#
#
# 🔹 處理第 313/1697 個：32405-g00
# ✅ 完成切割：32405-g00，共 1519 個 chunks
# 💾 完成 embedding 並將 32405-g00 存入 Chroma DB
#
#
# 🔹 處理第 314/1697 個：32532-g00
# ✅ 完成切割：32532-g00，共 378 個 chunks
# 💾 完成 embedding 並將 32532-g00 存入 Chroma DB
#
#
# 🔹 處理第 315/1697 個：32511-g00
# ✅ 完成切割：32511-g00，共 86 個 chunks
# 💾 完成 embedding 並將 32511-g00 存入 Chroma DB
#
#
# 🔹 處理第 316/1697 個：32406-g00
# ✅ 完成切割：32406-g00，共 1088 個 chunks
# 💾 完成 embedding 並將 32406-g00 存入 Chroma DB
#
#
# 🔹 處理第 317/1697 個：32901-g00
# ✅ 完成切割：32901-g00，共 129 個 chunks
# 💾 完成 embedding 並將 32901-g00 存入 Chroma DB
#
#
# 🔹 處理第 318/1697 個：32150-g00
# ✅ 完成切割：32150-g00，共 170 個 chunks
# 💾 完成 embedding 並將 32150-g00 存入 Chroma DB
#
#
# 🔹 處理第 319/1697 個：32270-g00
# ✅ 完成切割：32270-g00，共 633 個 chunks
# 💾 完成 embedding 並將 32270-g00 存入 Chroma DB
#
#
# 🔹 處理第 320/1697 個：32181-g00
# ✅ 完成切割：32181-g00，共 143 個 chunks
# 💾 完成 embedding 並將 32181-g00 存入 Chroma DB
#
#
# 🔹 處理第 321/1697 個：32435-g00
# ✅ 完成切割：32435-g00，共 114 個 chunks
# 💾 完成 embedding 並將 32435-g00 存入 Chroma DB
#
#
# 🔹 處理第 322/1697 個：55919-g00
# ✅ 完成切割：55919-g00，共 23 個 chunks
# 💾 完成 embedding 並將 55919-g00 存入 Chroma DB
#
#
# 🔹 處理第 323/1697 個：55216-g00
# ✅ 完成切割：55216-g00，共 35 個 chunks
# 💾 完成 embedding 並將 55216-g00 存入 Chroma DB
#
#
# 🔹 處理第 324/1697 個：55226-g00
# ✅ 完成切割：55226-g00，共 23 個 chunks
# 💾 完成 embedding 並將 55226-g00 存入 Chroma DB
#
#
# 🔹 處理第 325/1697 個：55217-g00
# ✅ 完成切割：55217-g00，共 19 個 chunks
# 💾 完成 embedding 並將 55217-g00 存入 Chroma DB
#
#
# 🔹 處理第 326/1697 個：55205-g00
# ✅ 完成切割：55205-g00，共 101 個 chunks
# 💾 完成 embedding 並將 55205-g00 存入 Chroma DB
#
#
# 🔹 處理第 327/1697 個：55218-g00
# ✅ 完成切割：55218-g00，共 19 個 chunks
# 💾 完成 embedding 並將 55218-g00 存入 Chroma DB
#
#
# 🔹 處理第 328/1697 個：55236-g00
# ✅ 完成切割：55236-g00，共 69 個 chunks
# 💾 完成 embedding 並將 55236-g00 存入 Chroma DB
#
#
# 🔹 處理第 329/1697 個：55253-g00
# ✅ 完成切割：55253-g00，共 37 個 chunks
# 💾 完成 embedding 並將 55253-g00 存入 Chroma DB
#
#
# 🔹 處理第 330/1697 個：55252-g00
# ✅ 完成切割：55252-g00，共 36 個 chunks
# 💾 完成 embedding 並將 55252-g00 存入 Chroma DB
#
#
# 🔹 處理第 331/1697 個：55242-g00
# ✅ 完成切割：55242-g00，共 32 個 chunks
# 💾 完成 embedding 並將 55242-g00 存入 Chroma DB
#
#
# 🔹 處理第 332/1697 個：55251-g00
# ✅ 完成切割：55251-g00，共 67 個 chunks
# 💾 完成 embedding 並將 55251-g00 存入 Chroma DB
#
#
# 🔹 處理第 333/1697 個：55243-g00
# ✅ 完成切割：55243-g00，共 32 個 chunks
# 💾 完成 embedding 並將 55243-g00 存入 Chroma DB
#
#
# 🔹 處理第 334/1697 個：55241-g00
# ✅ 完成切割：55241-g00，共 44 個 chunks
# 💾 完成 embedding 並將 55241-g00 存入 Chroma DB
#
#
# 🔹 處理第 335/1697 個：34123-3-g30_s00-s0804
# ✅ 完成切割：34123-3-g30_s00-s0804，共 4831 個 chunks
# 💾 完成 embedding 並將 34123-3-g30_s00-s0804 存入 Chroma DB
#
#
# 🔹 處理第 336/1697 個：34131-g00
# ✅ 完成切割：34131-g00，共 711 個 chunks
# 💾 完成 embedding 並將 34131-g00 存入 Chroma DB
#
#
# 🔹 處理第 337/1697 個：34123-3-g30_s0805-sAnnexes
# ✅ 完成切割：34123-3-g30_s0805-sAnnexes，共 7074 個 chunks
# 💾 完成 embedding 並將 34123-3-g30_s0805-sAnnexes 存入 Chroma DB
#
#
# 🔹 處理第 338/1697 個：34926-g00
# ✅ 完成切割：34926-g00，共 64 個 chunks
# 💾 完成 embedding 並將 34926-g00 存入 Chroma DB
#
#
# 🔹 處理第 339/1697 個：34121-1-g20_s09
# ✅ 完成切割：34121-1-g20_s09，共 6352 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_s09 存入 Chroma DB
#
#
# 🔹 處理第 340/1697 個：34229-5-g80
# ✅ 完成切割：34229-5-g80，共 6653 個 chunks
# 💾 完成 embedding 並將 34229-5-g80 存入 Chroma DB
#
#
# 🔹 處理第 341/1697 個：34123-3-g30_cover
# ✅ 完成切割：34123-3-g30_cover，共 103 個 chunks
# 💾 完成 embedding 並將 34123-3-g30_cover 存入 Chroma DB
#
#
# 🔹 處理第 342/1697 個：34121-1-g20_sAnnexeG-AnnexL
# ✅ 完成切割：34121-1-g20_sAnnexeG-AnnexL，共 2148 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_sAnnexeG-AnnexL 存入 Chroma DB
#
#
# 🔹 處理第 343/1697 個：34124-g00
# ✅ 完成切割：34124-g00，共 337 個 chunks
# 💾 完成 embedding 並將 34124-g00 存入 Chroma DB
#
#
# 🔹 處理第 344/1697 個：34229-2-g80
# ✅ 完成切割：34229-2-g80，共 764 個 chunks
# 💾 完成 embedding 並將 34229-2-g80 存入 Chroma DB
#
#
# 🔹 處理第 345/1697 個：34121-1-g20_s10-s11
# ✅ 完成切割：34121-1-g20_s10-s11，共 1065 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_s10-s11 存入 Chroma DB
#
#
# 🔹 處理第 346/1697 個：34121-1-g20_s08a-s08f
# ✅ 完成切割：34121-1-g20_s08a-s08f，共 6390 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_s08a-s08f 存入 Chroma DB
#
#
# 🔹 處理第 347/1697 個：34229-3-g80
# ✅ 完成切割：34229-3-g80，共 802 個 chunks
# 💾 完成 embedding 並將 34229-3-g80 存入 Chroma DB
#
#
# 🔹 處理第 348/1697 個：34121-1-g20_s07
# ✅ 完成切割：34121-1-g20_s07，共 1294 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_s07 存入 Chroma DB
#
#
# 🔹 處理第 349/1697 個：34121-1-g20_s08g
# ✅ 完成切割：34121-1-g20_s08g，共 2383 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_s08g 存入 Chroma DB
#
#
# 🔹 處理第 350/1697 個：34121-1-g20_s00-s06
# ✅ 完成切割：34121-1-g20_s00-s06，共 8898 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_s00-s06 存入 Chroma DB
#
#
# 🔹 處理第 351/1697 個：34109-g00
# ✅ 完成切割：34109-g00，共 322 個 chunks
# 💾 完成 embedding 並將 34109-g00 存入 Chroma DB
#
#
# 🔹 處理第 352/1697 個：34121-1-g20_sAnnexA-sAnnexF
# ✅ 完成切割：34121-1-g20_sAnnexA-sAnnexF，共 4906 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_sAnnexA-sAnnexF 存入 Chroma DB
#
#
# 🔹 處理第 353/1697 個：34121-1-g20_cover
# ✅ 完成切割：34121-1-g20_cover，共 447 個 chunks
# 💾 完成 embedding 並將 34121-1-g20_cover 存入 Chroma DB
#
#
# 🔹 處理第 354/1697 個：34229-1-g70
# ✅ 完成切割：34229-1-g70，共 11366 個 chunks
# 💾 完成 embedding 並將 34229-1-g70 存入 Chroma DB
#
#
# 🔹 處理第 355/1697 個：43246-g00
# ✅ 完成切割：43246-g00，共 395 個 chunks
# 💾 完成 embedding 並將 43246-g00 存入 Chroma DB
#
#
# 🔹 處理第 356/1697 個：43020-g10
# ✅ 完成切割：43020-g10，共 1108 個 chunks
# 💾 完成 embedding 並將 43020-g10 存入 Chroma DB
#
#
# 🔹 處理第 357/1697 個：43052-g00
# ✅ 完成切割：43052-g00，共 267 個 chunks
# 💾 完成 embedding 並將 43052-g00 存入 Chroma DB
#
#
# 🔹 處理第 358/1697 個：43010-g00
# ✅ 完成切割：43010-g00，共 401 個 chunks
# 💾 完成 embedding 並將 43010-g00 存入 Chroma DB
#
#
# 🔹 處理第 359/1697 個：43318-g00
# ✅ 完成切割：43318-g00，共 1154 個 chunks
# 💾 完成 embedding 並將 43318-g00 存入 Chroma DB
#
#
# 🔹 處理第 360/1697 個：43026-g00
# ✅ 完成切割：43026-g00，共 130 個 chunks
# 💾 完成 embedding 並將 43026-g00 存入 Chroma DB
#
#
# 🔹 處理第 361/1697 個：43050-g00
# ✅ 完成切割：43050-g00，共 329 個 chunks
# 💾 完成 embedding 並將 43050-g00 存入 Chroma DB
#
#
# 🔹 處理第 362/1697 個：43045-g00
# ✅ 完成切割：43045-g00，共 358 個 chunks
# 💾 完成 embedding 並將 43045-g00 存入 Chroma DB
#
#
# 🔹 處理第 363/1697 個：43064-g00
# ✅ 完成切割：43064-g00，共 1287 個 chunks
# 💾 完成 embedding 並將 43064-g00 存入 Chroma DB
#
#
# 🔹 處理第 364/1697 個：43013-g00
# ✅ 完成切割：43013-g00，共 53 個 chunks
# 💾 完成 embedding 並將 43013-g00 存入 Chroma DB
#
#
# 🔹 處理第 365/1697 個：43030-g00
# ✅ 完成切割：43030-g00，共 348 個 chunks
# 💾 完成 embedding 並將 43030-g00 存入 Chroma DB
#
#
# 🔹 處理第 366/1697 個：43068-g00
# ✅ 完成切割：43068-g00，共 2464 個 chunks
# 💾 完成 embedding 並將 43068-g00 存入 Chroma DB
#
#
# 🔹 處理第 367/1697 個：43130-g00
# ✅ 完成切割：43130-g00，共 159 個 chunks
# 💾 完成 embedding 並將 43130-g00 存入 Chroma DB
#
#
# 🔹 處理第 368/1697 個：43051-g00
# ✅ 完成切割：43051-g00，共 590 個 chunks
# 💾 完成 embedding 並將 43051-g00 存入 Chroma DB
#
#
# 🔹 處理第 369/1697 個：43069-g00
# ✅ 完成切割：43069-g00，共 1054 個 chunks
# 💾 完成 embedding 並將 43069-g00 存入 Chroma DB
#
#
# 🔹 處理第 370/1697 個：43073-g00
# ✅ 完成切割：43073-g00，共 174 個 chunks
# 💾 完成 embedding 並將 43073-g00 存入 Chroma DB
#
#
# 🔹 處理第 371/1697 個：43902-g00
# ✅ 完成切割：43902-g00，共 1175 個 chunks
# 💾 完成 embedding 並將 43902-g00 存入 Chroma DB
#
#
# 🔹 處理第 372/1697 個：43059-g00
# ✅ 完成切割：43059-g00，共 964 個 chunks
# 💾 完成 embedding 並將 43059-g00 存入 Chroma DB
#
#
# 🔹 處理第 373/1697 個：43005-g00
# ✅ 完成切割：43005-g00，共 188 個 chunks
# 💾 完成 embedding 並將 43005-g00 存入 Chroma DB
#
#
# 🔹 處理第 374/1697 個：43901-g00
# ✅ 完成切割：43901-g00，共 346 個 chunks
# 💾 完成 embedding 並將 43901-g00 存入 Chroma DB
#
#
# 🔹 處理第 375/1697 個：43055-g00
# ✅ 完成切割：43055-g00，共 531 個 chunks
# 💾 完成 embedding 並將 43055-g00 存入 Chroma DB
#
#
# 🔹 處理第 376/1697 個：43022-g00
# ✅ 完成切割：43022-g00，共 257 個 chunks
# 💾 完成 embedding 並將 43022-g00 存入 Chroma DB
#
#
# 🔹 處理第 377/1697 個：43903-g00
# ✅ 完成切割：43903-g00，共 708 個 chunks
# 💾 完成 embedding 並將 43903-g00 存入 Chroma DB
#
#
# 🔹 處理第 378/1697 個：43129-g00
# ✅ 完成切割：43129-g00，共 1090 個 chunks
# 💾 完成 embedding 並將 43129-g00 存入 Chroma DB
#
#
# 🔹 處理第 379/1697 個：43058-g10
# ✅ 完成切割：43058-g10，共 468 個 chunks
# 💾 完成 embedding 並將 43058-g10 存入 Chroma DB
#
#
# 🔹 處理第 380/1697 個：21101-g10
# ✅ 完成切割：21101-g10，共 32 個 chunks
# 💾 完成 embedding 並將 21101-g10 存入 Chroma DB
#
#
# 🔹 處理第 381/1697 個：21801-g30
# ✅ 完成切割：21801-g30，共 55 個 chunks
# 💾 完成 embedding 並將 21801-g30 存入 Chroma DB
#
#
# 🔹 處理第 382/1697 個：21916-g20
# ✅ 完成切割：21916-g20，共 2714 個 chunks
# 💾 完成 embedding 並將 21916-g20 存入 Chroma DB
#
#
# 🔹 處理第 383/1697 個：21201-g10
# ✅ 完成切割：21201-g10，共 25 個 chunks
# 💾 完成 embedding 並將 21201-g10 存入 Chroma DB
#
#
# 🔹 處理第 384/1697 個：21905-g00
# ✅ 完成切割：21905-g00，共 714 個 chunks
# 💾 完成 embedding 並將 21905-g00 存入 Chroma DB
#
#
# 🔹 處理第 385/1697 個：21205-g10
# ✅ 完成切割：21205-g10，共 16 個 chunks
# 💾 完成 embedding 並將 21205-g10 存入 Chroma DB
#
#
# 🔹 處理第 386/1697 個：21202-g00
# ✅ 完成切割：21202-g00，共 27 個 chunks
# 💾 完成 embedding 並將 21202-g00 存入 Chroma DB
#
#
# 🔹 處理第 387/1697 個：21111-g10
# ✅ 完成切割：21111-g10，共 181 個 chunks
# 💾 完成 embedding 並將 21111-g10 存入 Chroma DB
#
#
# 🔹 處理第 388/1697 個：21900-g40
# ✅ 完成切割：21900-g40，共 35 個 chunks
# 💾 完成 embedding 並將 21900-g40 存入 Chroma DB
#
#
# 🔹 處理第 389/1697 個：49031-g00
# ✅ 完成切割：49031-g00，共 722 個 chunks
# 💾 完成 embedding 並將 49031-g00 存入 Chroma DB
#
#
# 🔹 處理第 390/1697 個：49008-g00
# ✅ 完成切割：49008-g00，共 102 個 chunks
# 💾 完成 embedding 並將 49008-g00 存入 Chroma DB
#
#
# 🔹 處理第 391/1697 個：49995-g00
# ✅ 完成切割：49995-g00，共 87 個 chunks
# 💾 完成 embedding 並將 49995-g00 存入 Chroma DB
#
#
# 🔹 處理第 392/1697 個：51013-g10
# ✅ 完成切割：51013-g10，共 5030 個 chunks
# 💾 完成 embedding 並將 51013-g10 存入 Chroma DB
#
#
# 🔹 處理第 393/1697 個：51026-g00
# ✅ 完成切割：51026-g00，共 148 個 chunks
# 💾 完成 embedding 並將 51026-g00 存入 Chroma DB
#
#
# 🔹 處理第 394/1697 個：51021-g00
# ✅ 完成切割：51021-g00，共 3474 個 chunks
# 💾 完成 embedding 並將 51021-g00 存入 Chroma DB
#
#
# 🔹 處理第 395/1697 個：51010-4-g10
# ✅ 完成切割：51010-4-g10，共 5009 個 chunks
# 💾 完成 embedding 並將 51010-4-g10 存入 Chroma DB
#
#
# 🔹 處理第 396/1697 個：25469-g00
# ✅ 完成切割：25469-g00，共 629 個 chunks
# 💾 完成 embedding 並將 25469-g00 存入 Chroma DB
#
#
# 🔹 處理第 397/1697 個：25213-g00
# ✅ 完成切割：25213-g00，共 511 個 chunks
# 💾 完成 embedding 並將 25213-g00 存入 Chroma DB
#
#
# 🔹 處理第 398/1697 個：25212-g00
# ✅ 完成切割：25212-g00，共 1749 個 chunks
# 💾 完成 embedding 並將 25212-g00 存入 Chroma DB
#
#
# 🔹 處理第 399/1697 個：25956-g00
# ✅ 完成切割：25956-g00，共 320 個 chunks
# 💾 完成 embedding 並將 25956-g00 存入 Chroma DB
#
#
# 🔹 處理第 400/1697 個：25102-g00
# ✅ 完成切割：25102-g00，共 2038 個 chunks
# 💾 完成 embedding 並將 25102-g00 存入 Chroma DB
#
#
# 🔹 處理第 401/1697 個：25430-g00
# ✅ 完成切割：25430-g00，共 199 個 chunks
# 💾 完成 embedding 並將 25430-g00 存入 Chroma DB
#
#
# 🔹 處理第 402/1697 個：25422-g00
# ✅ 完成切割：25422-g00，共 60 個 chunks
# 💾 完成 embedding 並將 25422-g00 存入 Chroma DB
#
#
# 🔹 處理第 403/1697 個：25462-g00
# ✅ 完成切割：25462-g00，共 14 個 chunks
# 💾 完成 embedding 並將 25462-g00 存入 Chroma DB
#
#
# 🔹 處理第 404/1697 個：25460-g00
# ✅ 完成切割：25460-g00，共 14 個 chunks
# 💾 完成 embedding 並將 25460-g00 存入 Chroma DB
#
#
# 🔹 處理第 405/1697 個：25308-g00
# ✅ 完成切割：25308-g00，共 754 個 chunks
# 💾 完成 embedding 並將 25308-g00 存入 Chroma DB
#
#
# 🔹 處理第 406/1697 個：25903-g00
# ✅ 完成切割：25903-g00，共 1210 個 chunks
# 💾 完成 embedding 並將 25903-g00 存入 Chroma DB
#
#
# 🔹 處理第 407/1697 個：25214-g00
# ✅ 完成切割：25214-g00，共 1875 個 chunks
# 💾 完成 embedding 並將 25214-g00 存入 Chroma DB
#
#
# 🔹 處理第 408/1697 個：25402-g00
# ✅ 完成切割：25402-g00，共 546 個 chunks
# 💾 完成 embedding 並將 25402-g00 存入 Chroma DB
#
#
# 🔹 處理第 409/1697 個：25912-g00
# ✅ 完成切割：25912-g00，共 721 個 chunks
# 💾 完成 embedding 並將 25912-g00 存入 Chroma DB
#
#
# 🔹 處理第 410/1697 個：25410-g00
# ✅ 完成切割：25410-g00，共 248 個 chunks
# 💾 完成 embedding 並將 25410-g00 存入 Chroma DB
#
#
# 🔹 處理第 411/1697 個：25963-g00
# ✅ 完成切割：25963-g00，共 744 個 chunks
# 💾 完成 embedding 並將 25963-g00 存入 Chroma DB
#
#
# 🔹 處理第 412/1697 個：25301-g00
# ✅ 完成切割：25301-g00，共 473 個 chunks
# 💾 完成 embedding 並將 25301-g00 存入 Chroma DB
#
#
# 🔹 處理第 413/1697 個：25321-g00
# ✅ 完成切割：25321-g00，共 2243 個 chunks
# 💾 完成 embedding 並將 25321-g00 存入 Chroma DB
#
#
# 🔹 處理第 414/1697 個：25222-g00
# ✅ 完成切割：25222-g00，共 1302 個 chunks
# 💾 完成 embedding 並將 25222-g00 存入 Chroma DB
#
#
# 🔹 處理第 415/1697 個：25943-g00
# ✅ 完成切割：25943-g00，共 95 個 chunks
# 💾 完成 embedding 並將 25943-g00 存入 Chroma DB
#
#
# 🔹 處理第 416/1697 個：25412-g00
# ✅ 完成切割：25412-g00，共 84 個 chunks
# 💾 完成 embedding 並將 25412-g00 存入 Chroma DB
#
#
# 🔹 處理第 417/1697 個：25211-g00
# ✅ 完成切割：25211-g00，共 675 個 chunks
# 💾 完成 embedding 並將 25211-g00 存入 Chroma DB
#
#
# 🔹 處理第 418/1697 個：25996-g00
# ✅ 完成切割：25996-g00，共 387 個 chunks
# 💾 完成 embedding 並將 25996-g00 存入 Chroma DB
#
#
# 🔹 處理第 419/1697 個：25116-g00
# ✅ 完成切割：25116-g00，共 224 個 chunks
# 💾 完成 embedding 並將 25116-g00 存入 Chroma DB
#
#
# 🔹 處理第 420/1697 個：25324-g00
# ✅ 完成切割：25324-g00，共 186 個 chunks
# 💾 完成 embedding 並將 25324-g00 存入 Chroma DB
#
#
# 🔹 處理第 421/1697 個：25105-g00
# ✅ 完成切割：25105-g00，共 1110 個 chunks
# 💾 完成 embedding 並將 25105-g00 存入 Chroma DB
#
#
# 🔹 處理第 422/1697 個：25424-g00
# ✅ 完成切割：25424-g00，共 76 個 chunks
# 💾 完成 embedding 並將 25424-g00 存入 Chroma DB
#
#
# 🔹 處理第 423/1697 個：25221-g00
# ✅ 完成切割：25221-g00，共 2351 個 chunks
# 💾 完成 embedding 並將 25221-g00 存入 Chroma DB
#
#
# 🔹 處理第 424/1697 個：25427-g00
# ✅ 完成切割：25427-g00，共 390 個 chunks
# 💾 完成 embedding 並將 25427-g00 存入 Chroma DB
#
#
# 🔹 處理第 425/1697 個：25305-g00
# ✅ 完成切割：25305-g00，共 1126 個 chunks
# 💾 完成 embedding 並將 25305-g00 存入 Chroma DB
#
#
# 🔹 處理第 426/1697 個：25951-g00
# ✅ 完成切割：25951-g00，共 562 個 chunks
# 💾 完成 embedding 並將 25951-g00 存入 Chroma DB
#
#
# 🔹 處理第 427/1697 個：25471-g00
# ✅ 完成切割：25471-g00，共 438 個 chunks
# 💾 完成 embedding 並將 25471-g00 存入 Chroma DB
#
#
# 🔹 處理第 428/1697 個：25142-g00
# ✅ 完成切割：25142-g00，共 3183 個 chunks
# 💾 完成 embedding 並將 25142-g00 存入 Chroma DB
#
#
# 🔹 處理第 429/1697 個：25433-g00
# ✅ 完成切割：25433-g00，共 15408 個 chunks
# 💾 完成 embedding 並將 25433-g00 存入 Chroma DB
#
#
# 🔹 處理第 430/1697 個：25201-g00
# ✅ 完成切割：25201-g00，共 127 個 chunks
# 💾 完成 embedding 並將 25201-g00 存入 Chroma DB
#
#
# 🔹 處理第 431/1697 個：25423-g00
# ✅ 完成切割：25423-g00，共 13556 個 chunks
# 💾 完成 embedding 並將 25423-g00 存入 Chroma DB
#
#
# 🔹 處理第 432/1697 個：25322-g00
# ✅ 完成切割：25322-g00，共 931 個 chunks
# 💾 完成 embedding 並將 25322-g00 存入 Chroma DB
#
#
# 🔹 處理第 433/1697 個：25929-g00
# ✅ 完成切割：25929-g00，共 89 個 chunks
# 💾 完成 embedding 並將 25929-g00 存入 Chroma DB
#
#
# 🔹 處理第 434/1697 個：25414-g00
# ✅ 完成切割：25414-g00，共 138 個 chunks
# 💾 完成 embedding 並將 25414-g00 存入 Chroma DB
#
#
# 🔹 處理第 435/1697 個：25319-g00
# ✅ 完成切割：25319-g00，共 847 個 chunks
# 💾 完成 embedding 並將 25319-g00 存入 Chroma DB
#
#
# 🔹 處理第 436/1697 個：25143-g00
# ✅ 完成切割：25143-g00，共 1244 個 chunks
# 💾 完成 embedding 並將 25143-g00 存入 Chroma DB
#
#
# 🔹 處理第 437/1697 個：25446-g00
# ✅ 完成切割：25446-g00，共 150 個 chunks
# 💾 完成 embedding 並將 25446-g00 存入 Chroma DB
#
#
# 🔹 處理第 438/1697 個：25173-g00
# ✅ 完成切割：25173-g00，共 304 個 chunks
# 💾 完成 embedding 並將 25173-g00 存入 Chroma DB
#
#
# 🔹 處理第 439/1697 個：25153-g00
# ✅ 完成切割：25153-g00，共 522 個 chunks
# 💾 完成 embedding 並將 25153-g00 存入 Chroma DB
#
#
# 🔹 處理第 440/1697 個：25968-g00
# ✅ 完成切割：25968-g00，共 206 個 chunks
# 💾 完成 embedding 並將 25968-g00 存入 Chroma DB
#
#
# 🔹 處理第 441/1697 個：25444-g00
# ✅ 完成切割：25444-g00，共 38 個 chunks
# 💾 完成 embedding 並將 25444-g00 存入 Chroma DB
#
#
# 🔹 處理第 442/1697 個：25942-g00
# ✅ 完成切割：25942-g00，共 1304 個 chunks
# 💾 完成 embedding 並將 25942-g00 存入 Chroma DB
#
#
# 🔹 處理第 443/1697 個：25484-g00
# ✅ 完成切割：25484-g00，共 131 個 chunks
# 💾 完成 embedding 並將 25484-g00 存入 Chroma DB
#
#
# 🔹 處理第 444/1697 個：25432-g00
# ✅ 完成切割：25432-g00，共 42 個 chunks
# 💾 完成 embedding 並將 25432-g00 存入 Chroma DB
#
#
# 🔹 處理第 445/1697 個：25111-g00
# ✅ 完成切割：25111-g00，共 159 個 chunks
# 💾 完成 embedding 並將 25111-g00 存入 Chroma DB
#
#
# 🔹 處理第 446/1697 個：25141-g00
# ✅ 完成切割：25141-g00，共 3435 個 chunks
# 💾 完成 embedding 並將 25141-g00 存入 Chroma DB
#
#
# 🔹 處理第 447/1697 個：25435-g00
# ✅ 完成切割：25435-g00，共 544 個 chunks
# 💾 完成 embedding 並將 25435-g00 存入 Chroma DB
#
#
# 🔹 處理第 448/1697 個：25411-g00
# ✅ 完成切割：25411-g00，共 51 個 chunks
# 💾 完成 embedding 並將 25411-g00 存入 Chroma DB
#
#
# 🔹 處理第 449/1697 個：25421-g00
# ✅ 完成切割：25421-g00，共 15 個 chunks
# 💾 完成 embedding 並將 25421-g00 存入 Chroma DB
#
#
# 🔹 處理第 450/1697 個：25420-g00
# ✅ 完成切割：25420-g00，共 202 個 chunks
# 💾 完成 embedding 並將 25420-g00 存入 Chroma DB
#
#
# 🔹 處理第 451/1697 個：25303-g00
# ✅ 完成切割：25303-g00，共 412 個 chunks
# 💾 完成 embedding 並將 25303-g00 存入 Chroma DB
#
#
# 🔹 處理第 452/1697 個：25300-g10
# ✅ 完成切割：25300-g10，共 233 個 chunks
# 💾 完成 embedding 並將 25300-g10 存入 Chroma DB
#
#
# 🔹 處理第 453/1697 個：25302-g00
# ✅ 完成切割：25302-g00，共 1075 個 chunks
# 💾 完成 embedding 並將 25302-g00 存入 Chroma DB
#
#
# 🔹 處理第 454/1697 個：25453-g00
# ✅ 完成切割：25453-g00，共 2979 個 chunks
# 💾 完成 embedding 並將 25453-g00 存入 Chroma DB
#
#
# 🔹 處理第 455/1697 個：25104-g00
# ✅ 完成切割：25104-g00，共 1823 個 chunks
# 💾 完成 embedding 並將 25104-g00 存入 Chroma DB
#
#
# 🔹 處理第 456/1697 個：25225-g00
# ✅ 完成切割：25225-g00，共 322 個 chunks
# 💾 完成 embedding 並將 25225-g00 存入 Chroma DB
#
#
# 🔹 處理第 457/1697 個：25914-g00
# ✅ 完成切割：25914-g00，共 1324 個 chunks
# 💾 完成 embedding 並將 25914-g00 存入 Chroma DB
#
#
# 🔹 處理第 458/1697 個：25215-g00
# ✅ 完成切割：25215-g00，共 277 個 chunks
# 💾 完成 embedding 並將 25215-g00 存入 Chroma DB
#
#
# 🔹 處理第 459/1697 個：25967-g00
# ✅ 完成切割：25967-g00，共 658 個 chunks
# 💾 完成 embedding 並將 25967-g00 存入 Chroma DB
#
#
# 🔹 處理第 460/1697 個：25906-g00
# ✅ 完成切割：25906-g00，共 267 個 chunks
# 💾 完成 embedding 並將 25906-g00 存入 Chroma DB
#
#
# 🔹 處理第 461/1697 個：25401-g00
# ✅ 完成切割：25401-g00，共 554 個 chunks
# 💾 完成 embedding 並將 25401-g00 存入 Chroma DB
#
#
# 🔹 處理第 462/1697 個：25466-g00
# ✅ 完成切割：25466-g00，共 24 個 chunks
# 💾 完成 embedding 並將 25466-g00 存入 Chroma DB
#
#
# 🔹 處理第 463/1697 個：25415-g00
# ✅ 完成切割：25415-g00，共 541 個 chunks
# 💾 完成 embedding 並將 25415-g00 存入 Chroma DB
#
#
# 🔹 處理第 464/1697 個：25431-g00
# ✅ 完成切割：25431-g00，共 16 個 chunks
# 💾 完成 embedding 並將 25431-g00 存入 Chroma DB
#
#
# 🔹 處理第 465/1697 個：25451-g00
# ...
#  - 29515-g70           : 607 chunks
#  - 29205-g00           : 285 chunks
#  - 29526-g70           : 377 chunks
#  - 29335-g00           : 142 chunks
#  - 29228-g10           : 1031 chunks
#  - 29244-gc1           : 6250 chunks
#  - 29554-g80           : 437 chunks
#  - 29525-gc0           : 661 chunks
#  - 29060-g10           : 2715 chunks
#  - 29513-gc0           : 1515 chunks
#  - 29549-g60           : 865 chunks
#  - 29282-g00           : 39 chunks
#  - 29165-g60           : 2590 chunks
#  - 29002-g40           : 5498 chunks
#  - 29551-gb0           : 369 chunks
#  - 29540-ga0           : 365 chunks
#  - 29541-g50           : 408 chunks
#  - 29277-g00           : 85 chunks
#  - 29281-g20           : 368 chunks
#  - 29503-gg0           : 4134 chunks
#  - 29673-g70           : 467 chunks
#  - 29275-g00           : 1291 chunks
#  - 29542-g60           : 149 chunks
#  - 29544-g30           : 117 chunks
#  - 29173-g00           : 159 chunks
#  - 29500-gf0           : 1527 chunks
#  - 29594-g70           : 407 chunks
#  - 29658-g00           : 324 chunks
#  - 29292-g00           : 981 chunks
#  - 29519-gc0           : 1832 chunks
#  - 29364-g00           : 645 chunks
#  - 29305-g00           : 873 chunks
#  - 29007-g00           : 1430 chunks
#  - 29675-g50           : 280 chunks
#  - 29212-g40           : 4540 chunks
#  - 29909-g00           : 253 chunks
#  - 29509-ga0           : 786 chunks
#  - 29808-g00           : 122 chunks
#  - 29013-g00           : 170 chunks
#  - 29389-g00           : 209 chunks
#  - 29522-gf0           : 2215 chunks
#  - 29517-g50           : 401 chunks
#  - 29508-gb0           : 618 chunks
#  - 29512-gh0           : 3441 chunks
#  - 29215-g00           : 1069 chunks
#  - 29531-g80           : 820 chunks
#  - 29504-gb0           : 371 chunks
#  - 35201-g00           : 109 chunks
#  - 35934-g00           : 196 chunks
#  - 35231-g00           : 207 chunks
#  - 35935-g00           : 18 chunks
#  - 35207-g00           : 158 chunks
#  - 35204-g00           : 83 chunks
#  - 35221-g00           : 18 chunks
#  - 35208-g00           : 142 chunks
#  - 35232-g00           : 386 chunks
#  - 35919-g00           : 19 chunks
#  - 35222-g00           : 18 chunks
#  - 35936-g00           : 17 chunks
#  - 35205-g00           : 143 chunks
#  - 35924-g00           : 18 chunks
#  - 35203-g00           : 137 chunks
#  - 35202-g00           : 134 chunks
#  - 35217-g00           : 19 chunks
#  - 35216-g00           : 19 chunks
#  - 35218-g00           : 19 chunks
#  - 35206-g00           : 293 chunks
#  - 35233-g00           : 149 chunks
#  - 35223-g00           : 18 chunks
#  - 35909-g00           : 328 chunks
#  - 35215-g00           : 19 chunks
#  - 48001-g00           : 49 chunks
#  - 48020-g00           : 260 chunks
#  - 48006-g00           : 318 chunks
#  - 48054-g00           : 29 chunks
#  - 48056-g00           : 83 chunks
#  - 48004-g00           : 26 chunks
#  - 48014-g00           : 34 chunks
#  - 48051-g00           : 47 chunks
#  - 48049-g00           : 564 chunks
#  - 48071-g00           : 191 chunks
#  - 48031-g00           : 203 chunks
#  - 48016-g00           : 646 chunks
#  - 48061-g00           : 390 chunks
#  - 48060-g00           : 476 chunks
#  - 48002-g00           : 128 chunks
#  - 48018-g00           : 2465 chunks
#  - 48052-g00           : 139 chunks
#  - 48103-g00           : 189 chunks
#  - 48008-g00           : 3113 chunks
#  - 48058-g00           : 688 chunks
#  - S4-040336_track_changes: 140 chunks
#  - 26922-g10           : 219 chunks
#  - 26954-g00           : 209 chunks
#  - 26118-g30           : 1032 chunks
#  - 26445-g20_2_s0502_s050203: 1158 chunks
#  - 26111-g00           : 104 chunks
#  - 26269-g00           : 179 chunks
#  - 26453-g00           : 38 chunks
#  - 26925-g00           : 372 chunks
#  - 26989-g00           : 733 chunks
#  - Attachment 1D_Selection Test plan (ST-LR): 320 chunks
#  - 26501-gc0           : 753 chunks
#  - S4-AHQ099 Test Plan Round Robin BGN rev 1: 7 chunks
#  - 26511-g20           : 315 chunks
#  - 26451-g00           : 31 chunks
#  - 26952-g10           : 783 chunks
#  - 26193-g00           : 196 chunks
#  - 26304-g00           : 196 chunks
#  - 26973-g10           : 337 chunks
#  - Results for information from ASR vendors: 20 chunks
#  - Attachment 1E_Selection Test results (ST-LR): 533 chunks
#  - 26957-g00           : 521 chunks
#  - Readme_VAD2_TV_g10  : 25 chunks
#  - Ericsson,Nokia - codec performance (S4-040439): 42 chunks
#  - S4-151040 - ATempo_SPINE Round-robin tests conducted at Sony: 62 chunks
#  - 26245-g00           : 211 chunks
#  - 26444-g50           : 166 chunks
#  - 26074-g10           : 122 chunks
#  - 26404-g00           : 262 chunks
#  - 26346-gb1           : 3561 chunks
#  - 26929-g10           : 430 chunks
#  - 26445-g20_0_s00_s04 : 222 chunks
#  - 26445-g20_1_s05_s0501: 1674 chunks
#  - 26935-g00           : 1541 chunks
#  - SP-140740_S4-141407 - New Work Item on ATEMPO_SPINE: 26 chunks
#  - 26174-g00           : 112 chunks
#  - 26092-g00           : 106 chunks
#  - 26928-g10           : 1541 chunks
#  - 26430-g02           : 139 chunks
#  - S4-030248           : 14 chunks
#  - 26981-g00           : 413 chunks
#  - S4-151363 Report on ATeMPO_SPINE round-robin tests conducted at Orange: 50 chunks
#  - 26202-g00           : 127 chunks
#  - 26910-g00           : 270 chunks
#  - 26939-g10           : 602 chunks
#  - 26959-g00           : 456 chunks
#  - 26449-g00           : 44 chunks
#  - 26131-g00           : 905 chunks
#  - 26290-g00           : 930 chunks
#  - S4-040336           : 140 chunks
#  - 26194-g00           : 96 chunks
#  - 26978-g00           : 313 chunks
#  - 26204-g00           : 130 chunks
#  - Attachment 1F_Selection Test plan (ST-HR): 144 chunks
#  - 26268-g00           : 214 chunks
#  - 6330                : 144 chunks
#  - 26141-g00           : 120 chunks
#  - 26071-g00           : 85 chunks
#  - SP-020687           : 18 chunks
#  - 26273-g00           : 157 chunks
#  - S4-150559 - EVC Codec Evaluation including results_V12_1: 362 chunks
#  - 26348-g30           : 598 chunks
#  - 26949-g00           : 441 chunks
#  - ITU-T Standardization of G.722-1C, part1 (S4-050260): 205 chunks
#  - 26274-g00           : 185 chunks
#  - 26073-g00           : 246 chunks
#  - 26442-g40           : 69 chunks
#  - 26946-g00           : 417 chunks
#  - S4-151354 - ATempo_SPINE Round-robin tests conducted at Knowles: 49 chunks
#  - 26192-g00           : 109 chunks
#  - 26445-g20_9_s0602_s0607: 1257 chunks
#  - 26445-g20_5_s0503   : 2005 chunks
#  - 26447-g10           : 1218 chunks
#  - 26801-g00           : 273 chunks
#  - S4-040153           : 84 chunks
#  - 26174-f00           : 112 chunks
#  - 26975-g00           : 501 chunks
#  - 26402-g00           : 112 chunks
#  - 26948-g00           : 683 chunks
#  - 26244-g10           : 806 chunks
#  - 26093-g10           : 249 chunks
#  - S4-060157_Error_Conditions: 51 chunks
#  - 26231-g00           : 147 chunks
#  - 26191-g00           : 91 chunks
#  - 26090-g00           : 704 chunks
#  - 26923-g00           : 336 chunks
#  - 26101-g00           : 188 chunks
#  - 26173-g00           : 144 chunks
#  - 26452-g40           : 64 chunks
#  - 26904-g00           : 670 chunks
#  - 26454-g00           : 410 chunks
#  - 26944-g10           : 493 chunks
#  - 26445-g20_3_s050204_s050205: 82 chunks
#  - 26976-g00           : 973 chunks
#  - 26943-g00           : 126 chunks
#  - 26406-g00           : 82 chunks
#  - 26179-g00           : 61 chunks
#  - 26911-g00           : 120 chunks
#  - S4-151365 Results of Round Robin Test: 210 chunks
#  - Attachment 1B_Characterization Test results (CT-P1): 69 chunks
#  - ITU-T Standardization of G.722-1C, part2 (S4-050260): 47 chunks
#  - 26931-g00           : 375 chunks
#  - 26091-g00           : 101 chunks
#  - 26077-g00           : 608 chunks
#  - S4-040152 - WER under Channel Errors: 9 chunks
#  - 26969-g00           : 697 chunks
#  - 26445-g20_8_s06_s0601: 1107 chunks
#  - 26450-g00           : 34 chunks
#  - RS+LDPC             : 168 chunks
#  - 26445-g20_4_s050206 : 634 chunks
#  - 26843-g00           : 375 chunks
#  - 26140-g10           : 112 chunks
#  - 26102-g00           : 376 chunks
#  - 26347-g31           : 1367 chunks
#  - 26914-g00           : 172 chunks
#  - 26201-g00           : 178 chunks
#  - 26150-g00           : 268 chunks
#  - Attachment 1G_Selection Test results (ST-HR): 211 chunks
#  - 26936-g00           : 405 chunks
#  - S4-050187_Source code verification plan: 40 chunks
#  - 26115-g00           : 29 chunks
#  - 26891-g00           : 511 chunks
#  - 26247-g81           : 1660 chunks
#  - 26924-g10           : 1045 chunks
#  - 26985-g00           : 287 chunks
#  - 26281-g00           : 39 chunks
#  - 26445-g20_a_s0608_sHistory: 704 chunks
#  - 26950-g00           : 213 chunks
#  - 26094-g00           : 195 chunks
#  - Ericsson,Nokia - codec performance at very-low rates (S4-040710): 49 chunks
#  - 26512-gb0           : 1779 chunks
#  - S4-030543 test and processing plan 2.2: 87 chunks
#  - 26243-g00           : 139 chunks
#  - E-AAC+ configurations in characterisation test phase 2 (S4-050544): 18 chunks
#  - 26237-g00           : 1407 chunks
#  - 26114-gd0           : 5510 chunks
#  - 26104-g00           : 187 chunks
#  - 26246-g00           : 147 chunks
#  - 26902-g00           : 227 chunks
#  - 26411-g00           : 211 chunks
#  - 26142-g00           : 402 chunks
#  - 26260-g00           : 182 chunks
#  - 26132-g20           : 1584 chunks
#  - CodingTechnologies - Content dependency (S4-050710): 59 chunks
#  - 26190-g00           : 620 chunks
#  - AMR#09 Complexity and delay assessment: 124 chunks
#  - 26074-f00           : 121 chunks
#  - 26401-g00           : 92 chunks
#  - 26110-g00           : 137 chunks
#  - 26906-g00           : 525 chunks
#  - 26903-g00           : 202 chunks
#  - 26238-g62           : 570 chunks
#  - 26967-g00           : 232 chunks
#  - 26234-g20           : 1915 chunks
#  - 26850-g00           : 603 chunks
#  - 26307-g00           : 44 chunks
#  - 26905-g00           : 448 chunks
#  - 26443-g30           : 69 chunks
#  - 26947-g00           : 623 chunks
#  - 26412-g00           : 17 chunks
#  - 26103-g00           : 338 chunks
#  - 26921-g00           : 720 chunks
#  - AMR-WB+ configurations in characterisation test phase 2 (S4-050453): 39 chunks
#  - 26919-g20           : 344 chunks
#  - 26267-g00           : 349 chunks
#  - SP-030440           : 66 chunks
#  - S4-151343 HEAD acoustics Report on ATeMPO_SPINE round-robin tests conducted at HEAD acoustics _ : 199 chunks
#  - 26917-g00           : 681 chunks
#  - 26403-g00           : 232 chunks
#  - 26448-g00           : 267 chunks
#  - 26446-g00           : 42 chunks
#  - 26223-g40           : 405 chunks
#  - 26918-g00           : 1397 chunks
#  - 26226-g00           : 220 chunks
#  - 26117-g10           : 197 chunks
#  - Attachment 1C_Characterization Test results (CT-P2): 61 chunks
#  - 26907-g00           : 165 chunks
#  - 26909-g00           : 343 chunks
#  - 26410-g00           : 188 chunks
#  - 26116-g50           : 453 chunks
#  - 26937-g00           : 431 chunks
#  - 26938-g00           : 1175 chunks
#  - 26177-g00           : 24 chunks
#  - 26953-g00           : 485 chunks
#  - Attachment 1A_Characterization Test plan (CT-P1 and CT-P2 ): 213 chunks
#  - 26230-g00           : 181 chunks
#  - 26980-g00           : 1114 chunks
#  - 26445-g20_7_s0507_s0508: 104 chunks
#  - 26171-g00           : 69 chunks
#  - 26405-g00           : 88 chunks
#  - 26445-g20_6_s0504_s0506: 612 chunks
#  - 26139-g00           : 569 chunks
#  - 26259-g00           : 107 chunks
#  - README              : 1 chunks
#  - 33848-v0140 Clean   : 765 chunks
#  - 33905-g00           : 179 chunks
#  - 33102-g00           : 919 chunks
#  - 33127-gb0           : 973 chunks
#  - 33203-g10           : 1737 chunks
#  - 33848-v0140 Rm      : 763 chunks
#  - 33210-g40           : 269 chunks
#  - 33222-g10           : 385 chunks
#  - 33250-g00           : 125 chunks
#  - 33216-g70           : 128 chunks
#  - 33246-g00           : 789 chunks
#  - 33234-g00           : 58 chunks
#  - 33861-g10           : 800 chunks
#  - 33937-g00           : 1213 chunks
#  - 33117-ga0           : 1016 chunks
#  - 33141-g00           : 120 chunks
#  - 33926-g80           : 595 chunks
#  - 33980-g00           : 459 chunks
#  - 33303-g00           : 917 chunks
#  - 33853-110           : 484 chunks
#  - 33814-g01           : 175 chunks
#  - 33535-g20           : 150 chunks
#  - 33106-g00           : 244 chunks
#  - 33855-g10           : 1030 chunks
#  - 33223-g00           : 258 chunks
#  - 33122-g40           : 252 chunks
#  - 33536-g50           : 276 chunks
#  - 33517-g30           : 146 chunks
#  - 33836-g10           : 584 chunks
#  - 33856-g10           : 112 chunks
#  - 33515-g40           : 70 chunks
#  - 33401-g30           : 2023 chunks
#  - 33841-g10           : 347 chunks
#  - 33116-g10           : 105 chunks
#  - 33320-g00           : 534 chunks
#  - 33935-g00           : 87 chunks
#  - 33107-g00           : 3279 chunks
#  - 33845-040           : 242 chunks
#  - 33919-g00           : 160 chunks
#  - 33834-g10           : 399 chunks
#  - 33221-g00           : 242 chunks
#  - 33835-g10           : 767 chunks
#  - 33105-g00           : 167 chunks
#  - 33518-g20           : 66 chunks
#  - 33402-g00           : 735 chunks
#  - 33328-g10_clean     : 773 chunks
#  - 33110-g00           : 218 chunks
#  - 33187-g00           : 138 chunks
#  - 33514-g40           : 78 chunks
#  - 33180-gc0           : 2236 chunks
#  - 33819-g10           : 500 chunks
#  - 33204-g00           : 237 chunks
#  - 33511-ga0           : 172 chunks
#  - 33310-ge0           : 704 chunks
#  - 33434-g31           : 269 chunks
#  - 33809-0b0           : 1135 chunks
#  - 33512-g60           : 157 chunks
#  - 33519-g20           : 78 chunks
#  - 33815-g01           : 155 chunks
#  - 33220-g40           : 1077 chunks
#  - 33813-g00           : 361 chunks
#  - 33128-gf0           : 1997 chunks
#  - 33163-g20           : 362 chunks
#  - 33516-g20           : 48 chunks
#  - 33259-g00           : 210 chunks
#  - 33807-g01           : 296 chunks
#  - 33924-g00           : 433 chunks
#  - 33916-g10           : 498 chunks
#  - 33825-g01           : 312 chunks
#  - 33224-g00           : 222 chunks
#  - 33513-g30           : 90 chunks
#  - 33126-g50           : 227 chunks
#  - 33995-g00           : 345 chunks
#  - 33185-g00           : 86 chunks
#  - 33108-g50           : 4246 chunks
#  - Characteristics template for 3GPP 5G SRIT: 447 chunks
#  - 37466-g00           : 545 chunks
#  - 37144-g00           : 620 chunks
#  - 37910-g10           : 2265 chunks
#  - 37824-g00           : 296 chunks
#  - 37900-g00           : 1172 chunks
#  - 37461-g10           : 93 chunks
#  - 37716-00-00-g00     : 636 chunks
#  - 37114-g10           : 343 chunks
#  - Characteristics template for 3GPP 5G NR RIT: 452 chunks
#  - 37941-g60           : 3486 chunks
#  - 37823-g00           : 244 chunks
#  - 37571-3-ge0         : 1626 chunks
#  - 37716-21-21-g10     : 10561 chunks
#  - 37716-41-11-g00     : 400 chunks
#  - 37976-g00           : 881 chunks
#  - 37145-1-ge0         : 5533 chunks
#  - 37716-11-11-g00     : 8495 chunks
#  - 37571-2-gg0         : 85 chunks
#  - 37213-gc0           : 429 chunks
#  - 37113-g40           : 548 chunks
#  - 37716-21-11-g10     : 3677 chunks
#  - 37472-g20           : 57 chunks
#  - 37106-g10           : 36 chunks
#  - 37571-5-gb0         : 95 chunks
#  - 37816-g00           : 409 chunks
#  - 37145-2-gf0         : 6107 chunks
#  - 37105-ge0           : 4841 chunks
#  - 37471-g10           : 38 chunks
#  - Compliance template for 3GPP 5G SRIT: 196 chunks
#  - 37815-g00           : 121 chunks
#  - 37470-g20           : 114 chunks
#  - 37107-g30           : 72 chunks
#  - 37324-g30           : 95 chunks
#  - 37544-g20           : 3599 chunks
#  - Compliance template for 3GPP 5G NR RIT: 111 chunks
#  - 37571-1-gh0         : 564 chunks
#  - 37825-g00           : 180 chunks
#  - 37873-g00           : 118 chunks
#  - 37104-gi0           : 2092 chunks
#  - 37716-33-g00        : 135 chunks
#  - 37460-g00           : 58 chunks
#  - 37462-g00           : 149 chunks
#  - 37716-41-22-g00     : 225 chunks
#  - 37355-gc0           : 3756 chunks
#  - 37977-g00           : 1890 chunks
#  - 37716-31-11-g00     : 2334 chunks
#  - 37340-gd0           : 1269 chunks
#  - 37985-g10           : 436 chunks
#  - 37171-g10           : 367 chunks
#  - 37902-g00           : 331 chunks
#  - 37320-g80           : 387 chunks
#  - 37901-5-gb0         : 1247 chunks
#  - 37473-g90           : 1422 chunks
#  - 37571-4-g80         : 343 chunks
#
# 📦 總共切割出 1488141 個 chunks
# ===== Finished Processing in 2169.74 seconds =====

# %%
import os
from langchain.vectorstores import Chroma

root_db = "db_testinggggggggg"
all_sub_dbs = [d for d in os.listdir(root_db) if os.path.isdir(os.path.join(root_db, d))]

all_docs = []
for sub in all_sub_dbs:
    path = os.path.join(root_db, sub)
    db = Chroma(persist_directory=path, embedding_function=embedding)
    all_docs.extend(db.get()["documents"])

print(f"📦 合計讀入 {len(all_docs)} 筆資料")
print("📄 前兩筆：", all_docs[:2])
# Out:
# 📦 合計讀入 28510 筆資料
# 📄 前兩筆： ['+---------------------------------------------+-----------------------+ | 3GPP TS 31.121 V16.13.0 (2023-09) | | +=============================================+=======================+ | Technical Specification | | +---------------------------------------------+-----------------------+ | 3rd', '| 3rd Generation Partnership Project; | | | | | | Technical Specification Group Core Network | | | and Terminals; | | | | | | UICC-terminal interface; | | | | | | Universal Subscriber Identity Module | | | (USIM)\\ | | | application test specification | | | | | | (Release 16) | |']

# %%
import os
from langchain.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

# 參數設定
root_db_path = "db_testinggggggggg"
model_name = "sentence-transformers/all-MiniLM-L6-v2"
embedding = HuggingFaceEmbeddings(model_name=model_name, model_kwargs={"device": "cpu"})

# 查詢語句
query = "PDCCH configuration"
k = 5  # Top-K 全域搜尋數量

# 掃描所有資料夾
sub_dirs = [d for d in os.listdir(root_db_path) if os.path.isdir(os.path.join(root_db_path, d))]

all_results = []

for sub_dir in sub_dirs:
    sub_path = os.path.join(root_db_path, sub_dir)
    try:
        db = Chroma(persist_directory=sub_path, embedding_function=embedding)
        results = db.similarity_search(query, k=k)
        for r in results:
            r.metadata["source_spec"] = sub_dir  # 加上來源標籤
            all_results.append(r)
    except Exception as e:
        print(f"❌ 無法載入 {sub_dir}：{e}")

# 取前 K 筆（這裡不排序，只是合併後取前 k）
# 若你希望根據相似度排序，你需要使用 similarity_search_with_score
top_k_results = all_results[:k]

# 顯示結果
print(f"\n🔍 🔝 Top-{k} 結果（跨 DB）:")
for i, doc in enumerate(top_k_results, 1):
    print(f"\n--- Result {i} ---")
    print(f"來自 SPEC：{doc.metadata.get('source_spec', 'unknown')}")
    print(f"內容：\n{doc.page_content[:300]}...")
# Out:
# 🔍 🔝 Top-5 結果（跨 DB）:
#
# --- Result 1 ---
# 來自 SPEC：31121-gd0
# 內容：
# 1) During step b), the time of periods of inactivity on the UICC-Terminal interface shall not be longer than 30 seconds.
#
# 2) After step e), the Terminal shall terminate the call or PDP context within 5 s at the latest after having received the wrong response to the STATUS command....
#
# --- Result 2 ---
# 來自 SPEC：31121-gd0
# 內容：
# 12.11.4.2 Procedure
#
# a) The UE is powered on where the UICC is configured as defined in b) in the initial conditions.
#
# b) User request activate a PDP context. After receipt of ACTIVATE PDP CONTEXT REQUEST from the UE, the USS sends ACTIVATE PDP CONTEXT REJECT to the UE indicating:...
#
# --- Result 3 ---
# 來自 SPEC：31121-gd0
# 內容：
# a) The UE is powered on where the UICC is configured as defined in b) in the initial conditions.
#
# b) The user requests activation of a PDP context. After receipt of ACTIVATE PDP CONTEXT REQUEST from the UE, the USS sends ACTIVATE PDP CONTEXT REJECT to the UE indicating:...
#
# --- Result 4 ---
# 來自 SPEC：31121-gd0
# 內容：
# In general the values of the UICC configuration are identical to the default UICC, with the following exceptions:
#
# 4.8.1 EF~UST~ (USIM Service Table)
#
# Logically:
#
# Settings from clause 4.1 (Default UICC) of the present document apply with the following changes:...
#
# --- Result 5 ---
# 來自 SPEC：31121-gd0
# 內容：
# 8.4.4.2 Procedure
#
# a) A call shall be set up using the generic call setup for circuit switched call or to activate a PDP context....
